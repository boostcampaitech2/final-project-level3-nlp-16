# %%
import pandas as pd
from numpy import dot 
from numpy.linalg import norm

from transformers import AutoTokenizer

# %%
data = pd.read_csv('/Users/jhyun/Git/final-project-level3-nlp-16/data/raw_csv_data/600100001_data.csv')

# %% [markdown]
# 하나로, 카테고리,
# 카테고리별 csv 나눠서
# category

# %%
data.head()

# %% [markdown]
# ### 1. 전체 데이터에 대해서 hashtag vocab 만들기
# ### 2. title + description concat 연결 -> 2500개
# ### 3. 1번, 2번에 대해서 유사도 구하고 hashtag vocab에서 해시태그 뽑기

# %%
data

# %%
# 1. 전체 데이터에 대해서 hashtag vocab
hashtag_vocab = []
for tag in list(data['tag']):
    hashtag_vocab.extend(tag.split(','))


hashtag_vocab = list(set(hashtag_vocab))
hashtag_vocab # 2118

# %%
MODEL_NAME = 'klue/bert-base'
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
# tokenizer(hashtag_vocab)

# %%
hashtag_vector = []
hashtag_token = []
for id in tokenizer(hashtag_vocab)['input_ids']:
    id = id[1:-1]
    hashtag_vector.append(id)
    token = tokenizer.convert_ids_to_tokens(id)
    hashtag_token.append(token)
hashtag_vector[:3], hashtag_token[:3]

# %%
# 2. title + description concat

# %%
text_concat = []
for i in range(len(data)):
    row = data.iloc[i]
    text = row['title'] + ' ' + row['description']
    text = text.replace('\n', ' ')
    text_concat.append(text)

# %%
text_concat_vector = []
text_concat_token = []
for id in tokenizer(text_concat)['input_ids']:
    id = id[1:-1]
    text_concat_vector.append(id)
    token = tokenizer.convert_ids_to_tokens(id)
    text_concat_token.append(token)

# %%
# 3. 유사도 구하기

# %%
def make_matrix(feats, list_data):
    freq_list = []
    for feat in feats:
        freq = 0 
        for word in list_data: 
            if feat == word: 
                freq += 1 
        freq_list.append(freq) 
    return freq_list

# %%
result = []
for vocab_word in hashtag_token:
    sim = make_matrix(vocab_word, text_concat_token[0])
    word = tokenizer.convert_tokens_to_string(vocab_word)
    result.append([word, sum(sim)/len(sim)])

# %%
print(tokenizer.convert_tokens_to_string(text_concat_token[0]))

# %%
result_sort = sorted(result, key = lambda x : x[1], reverse=True)

# %%
result_sort[:10]

# %%
result_sort[-10:]

# %%
from pprint import pprint as pp
from es_api import ESApi

# %%
es = ESApi()
print(es.es_endpoint)
# Out:
# https://auto-tag.es.asia-northeast3.gcp.elastic-cloud.com:9243

# %%
res = es.es_search("배그")
pp(res)
# Out:
# [{'_id': '30433',
#   '_index': 'auto_tag',
#   '_score': 10.104085,
#   '_source': {'vocab': '배그'},
#   '_type': '_doc'},
#  {'_id': '1692',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 모니터'},
#   '_type': '_doc'},
#  {'_id': '2959',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 디아블로2'},
#   '_type': '_doc'},
#  {'_id': '3940',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 로스트아크'},
#   '_type': '_doc'},
#  {'_id': '6829',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '피파 배그'},
#   '_type': '_doc'},
#  {'_id': '7561',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '발로란트 배그'},
#   '_type': '_doc'},
#  {'_id': '14558',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 옵치'},
#   '_type': '_doc'},
#  {'_id': '18765',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 i5'},
#   '_type': '_doc'},
#  {'_id': '20273',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 디아2'},
#   '_type': '_doc'},
#  {'_id': '20320',
#   '_index': 'auto_tag',
#   '_score': 6.753194,
#   '_source': {'vocab': '배그 리니지2'},
#   '_type': '_doc'}]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/y3/sz_1yg3n37d6bch8mrb4dnv80000gn/T/ipykernel_11076/1316370732.py in <module>
# ----> 1 es.es_search("배그 잘 돌아가는 최신 컴퓨터")
#
# TypeError: es_search() takes 1 positional argument but 2 were given

# %%
from es_api import ESApi

# %%
es = ESApi()
# Out:
# test

# %%
es.load_elastic()
# Out:
# <Elasticsearch([{'host': 'auto-tag.es.asia-northeast3.gcp.elastic-cloud.com', 'port': 9243, 'use_ssl': True}])>

# %%
import json
with open("/Users/jhyun/Git/final-project-level3-nlp-16/data/es_data/pororo_ner_ver2.txt", "r") as file:
    
    renew = []
    strings = file.readlines()
    for str in strings:
        str = str.replace("\n", "")
        str = str.replace("  ", "")
        str = str.replace("\"", " ")
        renew.append(str)

for index, s in enumerate(renew):
    body = {"vocab" : s}
    print(json.dumps(body,ensure_ascii=False))
# Out:
# {"vocab": "서든 롤 피파 오버워치 서든 피파 오버워치 잘 돌아가는 최신 컴퓨터 팝니다. "}
# {"vocab": "여수포스기"}
# {"vocab": "im u160"}
# {"vocab": "저온창고저장고냉동기"}
# {"vocab": "삼성Ssd256g"}
# {"vocab": "IS ll"}
# {"vocab": "US"}
# {"vocab": "LG전자 32LN540B"}
# {"vocab": "11세대 I5 11400F"}
# {"vocab": "HDMI3 DP"}
# {"vocab": "PS S50"}
# {"vocab": "갤럭시탭S7 Fe 민트 LTE"}
# {"vocab": "셀피"}
# {"vocab": "DAVEN DMAX BLACK"}
# {"vocab": "배그게임"}
# {"vocab": "울트라기어 24MP59G"}
# {"vocab": "nm"}
# {"vocab": "A2E 35 80mm"}
# {"vocab": "허쉬3"}
# {"vocab": "A 60"}
# {"vocab": "찐폴라"}
# {"vocab": "J813S35ER"}
# {"vocab": "스포츠스트랩"}
# {"vocab": "삼성 NT270E5R i5 4210U"}
# {"vocab": "델 인스피론14"}
# {"vocab": "SKK ALV"}
# {"vocab": "T CON"}
# {"vocab": "SVF13N13"}
# {"vocab": "와이파이풀터치폰"}
# {"vocab": "샌디브릿지 i5 2500"}
# {"vocab": "EOS m100"}
# {"vocab": "콜옵"}
# {"vocab": "블랙 댐댐"}
# {"vocab": "KR시리"}
# {"vocab": "광시야"}
# {"vocab": "A벌킨 썬더볼트"}
# {"vocab": "Lg 27mk600m"}
# {"vocab": "맥스틸 G3300"}
# {"vocab": "cafe"}
# {"vocab": "미놀타 하이매틱 E"}
# {"vocab": "멀티메디아 5CH"}
# {"vocab": "무비카메라"}
# {"vocab": "EOS5 50mm f1 8 F794"}
# {"vocab": "애플워치 셀룰러 SE"}
# {"vocab": "7Ctr 3Dsls 7Csn 3D95694 7Chk"}
# {"vocab": "영아트필름카메라"}
# {"vocab": "블루투스 FM 라디오"}
# {"vocab": "SW270C"}
# {"vocab": "충전기"}
# {"vocab": "울트라와이드 34UM64"}
# {"vocab": "삼성오디세이 g5 커브드"}
# {"vocab": "우져"}
# {"vocab": "A3 흑백복합기"}
# {"vocab": "유디아 EDGE ED2425GFN"}
# {"vocab": "갤럭시 750ti"}
# {"vocab": "케이티셋탑박"}
# {"vocab": "Os 컴"}
# {"vocab": "32"}
# {"vocab": "320GBWindows 10 PRO"}
# {"vocab": "삼성레이저프린터기"}
# {"vocab": "ThinkPad T470"}
# {"vocab": "3600X"}
# {"vocab": "큐"}
# {"vocab": "갤럭시탭A 9 7"}
# {"vocab": "LG노트북 i5"}
# {"vocab": "sk텔레콤"}
# {"vocab": "부평서비스센테"}
# {"vocab": "프레임"}
# {"vocab": "FHD모니터"}
# {"vocab": "ASUS ROG SWIFT PG278QR"}
# {"vocab": "dimo 핑크"}
# {"vocab": "멀티허브"}
# {"vocab": "오버홀"}
# {"vocab": "Early"}
# {"vocab": "보조모니터"}
# {"vocab": "파나소닉 GH4 12 35mm f2 8"}
# {"vocab": "코어i5 9400f"}
# {"vocab": "이젤"}
# {"vocab": "xba n3ap"}
# {"vocab": "오멘HP"}
# {"vocab": "12 9 wifi"}
# {"vocab": "산요"}
# {"vocab": "NT800G5W XD51CPU i5 7300HQGPU GTX 1050RAM 8GBSSD"}
# {"vocab": "로지텍 키즈 투 고 블루투스 키보드"}
# {"vocab": "2470 아트 팝니다"}
# {"vocab": "윈10프"}
# {"vocab": "고폰"}
# {"vocab": "OPTIMUS X1"}
# {"vocab": "티비미라캐스트"}
# {"vocab": "제이투닷컴"}
# {"vocab": "LG 13UD580"}
# {"vocab": "엘지 i7 A510 쿼드코어"}
# {"vocab": "로지텍 G933s"}
# {"vocab": "화이트모니터"}
# {"vocab": "슬레이트PC"}
# {"vocab": "ASUS TUF Gaming B560M plus WiFi 소켓1200,M ATX"}
# {"vocab": ", 75 200mm f4 5"}
# {"vocab": "미놀타 하이매틱 AF 필름카메라"}
# {"vocab": "베컴폰2 v10"}
# {"vocab": "엠비에프"}
# {"vocab": "F2 8"}
# {"vocab": "KQ65QT90"}
# {"vocab": "아디다스"}
# {"vocab": "벨벳 블랙"}
# {"vocab": "와콤 DTK 2260 신티크"}
# {"vocab": "a55 dslr"}
# {"vocab": "F32TU870"}
# {"vocab": "램8 i5"}
# {"vocab": "인텔 G6405"}
# {"vocab": "F965"}
# {"vocab": "아이나비 LDWS"}
# {"vocab": "탐락백팩"}
# {"vocab": "카나다"}
# {"vocab": "DocuCentre IV C2265"}
# {"vocab": "짭틸러스pbt"}
# {"vocab": "노트북 i3 3217u"}
# {"vocab": "32qk500c"}
# {"vocab": "4k uhd"}
# {"vocab": "카페스피커"}
# {"vocab": "화일빌딩"}
# {"vocab": "sk2g 스카이 im 1000"}
# {"vocab": "D90 dslr"}
# {"vocab": "비스비케이스"}
# {"vocab": "펜탁스 ME SE 50mm f2 0 SMC M"}
# {"vocab": "소니 8G"}
# {"vocab": "fullhd"}
# {"vocab": "gta"}
# {"vocab": "ASC 06"}
# {"vocab": "오디세이 G7"}
# {"vocab": "140만원75UN7070"}
# {"vocab": "LG cyber p3000"}
# {"vocab": "듀얼 블루투스이어폰"}
# {"vocab": "옵티머스시크LG U 3g"}
# {"vocab": "팬택 앤 큐리텔"}
# {"vocab": "샤프너"}
# {"vocab": "피쳐"}
# {"vocab": "레이저 헌츠맨v2"}
# {"vocab": "페이커"}
# {"vocab": "코니카 레코더"}
# {"vocab": "Fisher"}
# {"vocab": "바밀로 MA87M Lovebirds"}
# {"vocab": "SONY a7m3"}
# {"vocab": "NT530U4C"}
# {"vocab": "SK 3g폰"}
# {"vocab": "폰프렌즈"}
# {"vocab": "파인뷰LX3000"}
# {"vocab": "엑티브 워시 세탁기"}
# {"vocab": "JDM"}
# {"vocab": "갤럭시 s21"}
# {"vocab": "블루투스키보드"}
# {"vocab": "I5 9400F"}
# {"vocab": "캐논 오토보이 S XL"}
# {"vocab": "QX3228"}
# {"vocab": "스테들러s"}
# {"vocab": "다나와"}
# {"vocab": "카카오프렌즈"}
# {"vocab": "NanoIps"}
# {"vocab": "화이트 커브드"}
# {"vocab": "무선 Adapter"}
# {"vocab": "FM2"}
# {"vocab": "카날스"}
# {"vocab": "갤럭시 워치4 pxg"}
# {"vocab": "노트북HD"}
# {"vocab": "Mu so 1"}
# {"vocab": "3RSYS R500"}
# {"vocab": "cj택배"}
# {"vocab": "카본"}
# {"vocab": "3060 6600XT"}
# {"vocab": "LG F610S"}
# {"vocab": "갤럭시 탭A 515"}
# {"vocab": "리코GR2"}
# {"vocab": "와이드 음료수냉장고"}
# {"vocab": "갤럭시 버즈 2 화이트"}
# {"vocab": "Lg oled"}
# {"vocab": "아티브 NT905SG3 K1GR"}
# {"vocab": "소니 바이오"}
# {"vocab": "OIO 4826 8617Lenovo ThinkPad X13 Gen 1 20T3 S2WY2GCPU"}
# {"vocab": "올림푸스 OZ 1 PANORAMA62"}
# {"vocab": "에디린"}
# {"vocab": "CKC V2"}
# {"vocab": "넥스디스털"}
# {"vocab": "라이젠 R5 2600"}
# {"vocab": "APS 필름"}
# {"vocab": "SUPER"}
# {"vocab": "MX537"}
# {"vocab": "OS 윈도우10프로"}
# {"vocab": "3Dkt2i20g8"}
# {"vocab": "소니a5100미러리스"}
# {"vocab": "0073APPLE"}
# {"vocab": "LOMO LC A"}
# {"vocab": "EOS 1100D"}
# {"vocab": "SK3G 175"}
# {"vocab": "삼성VGA"}
# {"vocab": "싸게"}
# {"vocab": "44mm"}
# {"vocab": "sRGB 100 DCI P3 90 HDMI"}
# {"vocab": "AMR 777"}
# {"vocab": "RTX3050Ti"}
# {"vocab": "갤럭시워치3 워치3 블랙"}
# {"vocab": "로닌sc"}
# {"vocab": "갤탭"}
# {"vocab": "맥북 프로 8 512G"}
# {"vocab": "Retina 4K"}
# {"vocab": "보조배터리"}
# {"vocab": "스트로만"}
# {"vocab": "RTX 2060"}
# {"vocab": "주고산 캐넌 200dii"}
# {"vocab": "후지 X T2"}
# {"vocab": "sb35"}
# {"vocab": "hp복합기"}
# {"vocab": "정격600w 85"}
# {"vocab": "G813"}
# {"vocab": "GA P75 D3"}
# {"vocab": "W800BT"}
# {"vocab": "올림푸스 Am 100"}
# {"vocab": "조텍 코리아"}
# {"vocab": "아주르"}
# {"vocab": "소니18 105렌즈 18 105"}
# {"vocab": "헨드폰"}
# {"vocab": "서브우퍼TF ISB"}
# {"vocab": "mx z 10"}
# {"vocab": "HW Q800A HW Q800A"}
# {"vocab": "레이저 파이어플라이V2"}
# {"vocab": "i5 3450"}
# {"vocab": "PDP TV"}
# {"vocab": "숫자패드"}
# {"vocab": "겔럭시워치"}
# {"vocab": "SCH W410"}
# {"vocab": "브로드웰 E"}
# {"vocab": "데이트룩스"}
# {"vocab": "51mGPU"}
# {"vocab": "치폴더폰"}
# {"vocab": "애플펜슬 프로1"}
# {"vocab": "SRT75HWEFBA"}
# {"vocab": "144포터블"}
# {"vocab": "맥북 프로M1 256"}
# {"vocab": "원키고스트"}
# {"vocab": "애플펜1"}
# {"vocab": "UAC2"}
# {"vocab": "9"}
# {"vocab": "씨메02light"}
# {"vocab": "450d"}
# {"vocab": "바이퍼 미니"}
# {"vocab": "체리키보드"}
# {"vocab": "삼성 DDR3 2gb X 2ea"}
# {"vocab": "우리엄마폰가게"}
# {"vocab": "BenQ ZOWIE XL2411K"}
# {"vocab": "ux534"}
# {"vocab": "GTX960"}
# {"vocab": "F2 8L"}
# {"vocab": "아크레스트"}
# {"vocab": "전자시계"}
# {"vocab": "롤게이밍"}
# {"vocab": "ApeosPort IV C5570 A3"}
# {"vocab": "hsdpa폰"}
# {"vocab": "Intel Core i7 7800XGPU"}
# {"vocab": "서피스 프로7 PUV 0023 i5 10th Gen intel"}
# {"vocab": "충"}
# {"vocab": "워드 2020"}
# {"vocab": "사무용빠른중고컴퓨터"}
# {"vocab": "RP 그"}
# {"vocab": "스타택 7760 7761 7760RA"}
# {"vocab": "TiTan12"}
# {"vocab": "액자"}
# {"vocab": "LG SU600"}
# {"vocab": "ADATA SU655"}
# {"vocab": "Canon 6d canon 24 70 f2"}
# {"vocab": "OA76K"}
# {"vocab": "누아르 스위프트"}
# {"vocab": "F801S"}
# {"vocab": "MSI 라데온 RX 6900 XT"}
# {"vocab": "eos m2"}
# {"vocab": "MUSE Phono amp"}
# {"vocab": "RF85R926201"}
# {"vocab": "삼성카메라"}
# {"vocab": "사무용전화기"}
# {"vocab": "TG DEEL"}
# {"vocab": "P S ONE Touch 200"}
# {"vocab": "SRM FLEX"}
# {"vocab": "흑백tv"}
# {"vocab": "전기자전거"}
# {"vocab": "Intel Core i5 9400F"}
# {"vocab": "동서식품"}
# {"vocab": "G C gtx 1650O"}
# {"vocab": "맥북에어2021"}
# {"vocab": "Lg wine"}
# {"vocab": "애플워치시리즈5"}
# {"vocab": "코튼 블루"}
# {"vocab": "데스에더 엘리크 게이밍 마우스"}
# {"vocab": "레이저 데스에더 엘리트"}
# {"vocab": "맥슨"}
# {"vocab": "SM R840"}
# {"vocab": "datelux a35"}
# {"vocab": "EOS M100"}
# {"vocab": "매직 키보드"}
# {"vocab": "이동식카드체"}
# {"vocab": "삼산점"}
# {"vocab": "닛시 사운드 SR122D 500W"}
# {"vocab": "엘지통돌이세탁기"}
# {"vocab": "AMOGA"}
# {"vocab": "턴테이블 스피커"}
# {"vocab": "부천갤럭시A9프로"}
# {"vocab": "WAS LX2J"}
# {"vocab": "그램17 17ZD95N GX56K"}
# {"vocab": "노트10 핑크"}
# {"vocab": "박스카메라"}
# {"vocab": "본체35X106"}
# {"vocab": "갤럭시Z폴드"}
# {"vocab": "AA배터리"}
# {"vocab": "SSD128"}
# {"vocab": "와콤디지타이져3"}
# {"vocab": "콘스탁 g1"}
# {"vocab": "알비날"}
# {"vocab": "라이카 DC SUMMILUX 25mmF1 4 ASPH"}
# {"vocab": "세라믹화이트"}
# {"vocab": "k100"}
# {"vocab": "LED DID 사이니지"}
# {"vocab": "디아블로2 1"}
# {"vocab": "s2740LB"}
# {"vocab": "앰프55000"}
# {"vocab": "롤 로스트아크 로아"}
# {"vocab": "Amazon"}
# {"vocab": "CW MLE23V1"}
# {"vocab": "부성"}
# {"vocab": "서피스 북"}
# {"vocab": "비봉중학교"}
# {"vocab": "sr 10"}
# {"vocab": "HORUSBENNU FX 30DL"}
# {"vocab": "퍼지줌카메라"}
# {"vocab": "속기 키보드"}
# {"vocab": "HORUS BENNU"}
# {"vocab": "에어팟 프로 pro"}
# {"vocab": "듀퐁폴더폰"}
# {"vocab": "asus x512dacpu 3500u"}
# {"vocab": "CASIO fx 350MS"}
# {"vocab": "nikka"}
# {"vocab": "오키드 블루 핑크"}
# {"vocab": "kh1300"}
# {"vocab": "Touch BarRAM"}
# {"vocab": "원스텝2"}
# {"vocab": "대구니콘센터"}
# {"vocab": "파워600"}
# {"vocab": "DDR4 16G 8G"}
# {"vocab": "바배"}
# {"vocab": "실루엣"}
# {"vocab": "승"}
# {"vocab": "cpu i3 3317U"}
# {"vocab": "5600x"}
# {"vocab": "H510"}
# {"vocab": "독립외장"}
# {"vocab": "유튜버카메라"}
# {"vocab": "5Dmark4"}
# {"vocab": "LG 울트라 HD AI ThinQ 4K"}
# {"vocab": "실버맥북"}
# {"vocab": "4K2K"}
# {"vocab": "GTX1050RAM"}
# {"vocab": "애플워치 시리즈2"}
# {"vocab": "Intel R Core TM i"}
# {"vocab": "55인치 55UN7850KNA"}
# {"vocab": "인티임프로"}
# {"vocab": "올"}
# {"vocab": "EOS 500D"}
# {"vocab": "브레이슬릿"}
# {"vocab": "앰프우퍼"}
# {"vocab": "커피레이크 R i7 9750HF"}
# {"vocab": "지포스 RTX3070 Ti OC D6X"}
# {"vocab": "canon"}
# {"vocab": "버즈1"}
# {"vocab": "Tower Stereo"}
# {"vocab": "lte 64gbs6"}
# {"vocab": "아이뮤즈 스톰북14 아폴로 플러스"}
# {"vocab": "RF카메라"}
# {"vocab": "롤 렉X"}
# {"vocab": "빔스크린"}
# {"vocab": "무선 불루투스 헤드폰헤드폰"}
# {"vocab": "UHD"}
# {"vocab": "QLED 55 UHD"}
# {"vocab": "화물차"}
# {"vocab": "카카오미니 라이언"}
# {"vocab": "AF 필름카메라"}
# {"vocab": "A20"}
# {"vocab": "삼성디지털프라자 보령점"}
# {"vocab": "CF400 4 75W X4"}
# {"vocab": "울트라스림폰"}
# {"vocab": "갤럭시탭 s6라"}
# {"vocab": "AF17N7970MF"}
# {"vocab": "건전"}
# {"vocab": "LG블랙라벨통돌이세탁기"}
# {"vocab": "소니 미러리스"}
# {"vocab": "나이키3"}
# {"vocab": "Britz BA SB2"}
# {"vocab": "X570 Aorus Pro"}
# {"vocab": "아이온 발로란트 카트"}
# {"vocab": "ION DS1"}
# {"vocab": "K403S"}
# {"vocab": "갤럭시 탭 S4"}
# {"vocab": "앤커코리아"}
# {"vocab": "고급사무용PC"}
# {"vocab": "삼성홈보이 SM T210L"}
# {"vocab": "40MM"}
# {"vocab": "삼성노트북9 METAL NT901X5L"}
# {"vocab": "Sandmar"}
# {"vocab": "브이모다사"}
# {"vocab": "미놀타 AF S QUARTZ DATE"}
# {"vocab": "Camera PowerShot Series"}
# {"vocab": "정품에어팟"}
# {"vocab": "10900kf cl16"}
# {"vocab": "보이런던 q92"}
# {"vocab": "라이카x2"}
# {"vocab": "대우냉장고 FR G244PDWE"}
# {"vocab": "싸이언 프리스타일아이리버"}
# {"vocab": "엘지 그램 14"}
# {"vocab": "스카이DMB폰"}
# {"vocab": "외장스토리지"}
# {"vocab": "갤럭시노트"}
# {"vocab": "마이크로 소프트"}
# {"vocab": "미니3"}
# {"vocab": "lg휘센"}
# {"vocab": "이블리"}
# {"vocab": "갤럭시탭7 0"}
# {"vocab": "애플이어팟"}
# {"vocab": "Vincent"}
# {"vocab": "블랙퍼플"}
# {"vocab": "게임용헤드셋"}
# {"vocab": "디지털 튜너"}
# {"vocab": "애플스페이스그레이마우스"}
# {"vocab": "아이폰5S"}
# {"vocab": "비비타 비스타 텔레 모터"}
# {"vocab": "지하철1,7호선"}
# {"vocab": "지니폰"}
# {"vocab": "코웨이공기청정기"}
# {"vocab": "구미3공장"}
# {"vocab": "야시카 하프 17"}
# {"vocab": "scanjet 2004"}
# {"vocab": "se 44mm"}
# {"vocab": "세종일렉트로마트"}
# {"vocab": "리니어 키보드"}
# {"vocab": "모하비"}
# {"vocab": "Xo v3 네이비블랙"}
# {"vocab": "지포스"}
# {"vocab": "라데온"}
# {"vocab": "LOREO 321 3D 스테레오 필름"}
# {"vocab": "SK직수정수기"}
# {"vocab": "RX100M3"}
# {"vocab": "LG T390"}
# {"vocab": "인텔i5 3570"}
# {"vocab": "해피해"}
# {"vocab": "디스플레이 15"}
# {"vocab": "삼성갤럭시 S21울트라"}
# {"vocab": "무선마우스"}
# {"vocab": "플라밍고"}
# {"vocab": "레인지 파인더"}
# {"vocab": "로그립 메스토스"}
# {"vocab": "BRONCO LP 턴테이블"}
# {"vocab": "오픈카톡"}
# {"vocab": "a2540"}
# {"vocab": "에어2"}
# {"vocab": "바코드"}
# {"vocab": "DDR4 캐쉬 SLC"}
# {"vocab": "32UN880"}
# {"vocab": "펜슬박스"}
# {"vocab": "42인치"}
# {"vocab": "APS"}
# {"vocab": "eos kiss5Eos kiss"}
# {"vocab": "원모띵"}
# {"vocab": "DSLR 500d"}
# {"vocab": "써멀그리스"}
# {"vocab": "S100 EF"}
# {"vocab": "슈퍼카"}
# {"vocab": "MD"}
# {"vocab": "스카이 IM R470S"}
# {"vocab": "MPS"}
# {"vocab": "AF S 3 5 4 5G"}
# {"vocab": "올드카메라"}
# {"vocab": "다빈치"}
# {"vocab": "맥북 키보드"}
# {"vocab": "i3 1005G1"}
# {"vocab": "스마트콤비"}
# {"vocab": "스톰체이서"}
# {"vocab": "ll120"}
# {"vocab": "색소폰"}
# {"vocab": "4K UHD Smart TV"}
# {"vocab": "BeoPlay HX"}
# {"vocab": "IOS"}
# {"vocab": "23WDLED"}
# {"vocab": "Wharfedale Diamond 8 4"}
# {"vocab": "베오사운드"}
# {"vocab": "gt1030"}
# {"vocab": "JBL CLIP4"}
# {"vocab": "윈"}
# {"vocab": "일반하드"}
# {"vocab": "eos30d"}
# {"vocab": "SK 800 SK3G 251"}
# {"vocab": "발로란트 프랙처"}
# {"vocab": "퍼니쳐스차일"}
# {"vocab": "대우동부"}
# {"vocab": "로즈핑크 95"}
# {"vocab": "마란츠리시버 2238"}
# {"vocab": "d5600"}
# {"vocab": "베리컴"}
# {"vocab": "라이젠 3600x"}
# {"vocab": "블루투스스피커"}
# {"vocab": "제나 77 S"}
# {"vocab": "익스 마우스"}
# {"vocab": "FLATRON 27EA53VQ"}
# {"vocab": "LED Tv"}
# {"vocab": "블랙베리 9000"}
# {"vocab": "갤럭시 탭E 8 0 SM T375S"}
# {"vocab": "AMU099AP"}
# {"vocab": "qhd TFG27Q14V"}
# {"vocab": "삼성 DEX"}
# {"vocab": "커즈와일"}
# {"vocab": "핫슈"}
# {"vocab": "하이룩"}
# {"vocab": "디지아트R290"}
# {"vocab": "오른위쪽"}
# {"vocab": "acer PREDATOR XB273U GX"}
# {"vocab": "EMMC"}
# {"vocab": "듀열모니터"}
# {"vocab": "144HZ"}
# {"vocab": "LG 매직스패이스"}
# {"vocab": "애플 프로"}
# {"vocab": "토핑김밥냉장고"}
# {"vocab": "h800"}
# {"vocab": "PHILIPS DTM3155"}
# {"vocab": "삼성 NX mini"}
# {"vocab": "넷플릭스TV"}
# {"vocab": "YAMATSUI"}
# {"vocab": "DP HDMI"}
# {"vocab": "삼성DDR4 8G"}
# {"vocab": "CASE COX RC 170T"}
# {"vocab": "4세대윈10"}
# {"vocab": "업스케일링"}
# {"vocab": "선박스피커"}
# {"vocab": "JBK 8902"}
# {"vocab": "램8 ssd256"}
# {"vocab": "앤커 Anker 사운드코어 모션플러스 30w"}
# {"vocab": "Tel OIO"}
# {"vocab": "DWF 15GAGC"}
# {"vocab": "나콘 v3 레볼루션 패드"}
# {"vocab": "n Parvola Ihagee Parvolar"}
# {"vocab": "220v"}
# {"vocab": "일체형 SE"}
# {"vocab": "삼성 AF zoom 800"}
# {"vocab": "비츠솔로프로팝"}
# {"vocab": "CL 32LNF10"}
# {"vocab": "헤어드라이기"}
# {"vocab": "업앤다운"}
# {"vocab": "AF 1 QD 필름카메라"}
# {"vocab": "번개톡이"}
# {"vocab": "외"}
# {"vocab": "크로우"}
# {"vocab": "롤퓨터"}
# {"vocab": "크리스탈폰"}
# {"vocab": "StylusPhoto R1800"}
# {"vocab": "실버 펜슬"}
# {"vocab": "텐키 뽐뿌"}
# {"vocab": "콕스COX"}
# {"vocab": "카본블랙"}
# {"vocab": "비스포크 키친핏"}
# {"vocab": "엘지 T390"}
# {"vocab": "EX78"}
# {"vocab": "LG A515 i5"}
# {"vocab": "usb20핀"}
# {"vocab": "갤럭시탭s7플러스 s7"}
# {"vocab": "무선 라벨기"}
# {"vocab": "FKH"}
# {"vocab": "펜탁스 미 슈퍼 필름카메라f1"}
# {"vocab": "13인치 m1"}
# {"vocab": "드립니다앱플레이어"}
# {"vocab": "셀카카메라"}
# {"vocab": "z6 z7 z6ii"}
# {"vocab": "winder 503cw"}
# {"vocab": "진공관"}
# {"vocab": "JBL EON206p"}
# {"vocab": "레노버"}
# {"vocab": "로켓레이크S"}
# {"vocab": "NT550XDA KG03Ghttps"}
# {"vocab": "901L T9000"}
# {"vocab": "R290"}
# {"vocab": "엘지g8"}
# {"vocab": "지윤텍"}
# {"vocab": "SD메모리카"}
# {"vocab": "iris 레티나"}
# {"vocab": "핵사코어 GTX1660ti"}
# {"vocab": "IM 6500"}
# {"vocab": "태블릿 64G"}
# {"vocab": "번들셋d3100"}
# {"vocab": "CPU i7 7820HQ 2"}
# {"vocab": "미니공기청정기"}
# {"vocab": "N950 오키드그레이"}
# {"vocab": "위닉스건조기"}
# {"vocab": "SSD모니터"}
# {"vocab": "들국화"}
# {"vocab": "32인치Z320"}
# {"vocab": "아몰레드빔"}
# {"vocab": "LTE Wi Fi Wi Fi5"}
# {"vocab": "1,200 1 NTSC 72 HDMI"}
# {"vocab": "히트펌퍼"}
# {"vocab": "SHW M340S"}
# {"vocab": "인켈 SP 858V"}
# {"vocab": "번들 이어폰"}
# {"vocab": "AF35ML 오토포커스"}
# {"vocab": "SATA Port 2"}
# {"vocab": "srchhow Cexpo1"}
# {"vocab": "엘피 레코드"}
# {"vocab": "버즈프로"}
# {"vocab": "덱헤슘 프로 청축 프로"}
# {"vocab": "낙하충격"}
# {"vocab": "갤럭시 j2 pro"}
# {"vocab": "캐논850D"}
# {"vocab": "오병이어잉크"}
# {"vocab": "polk Audio Hamp"}
# {"vocab": "블루투스 코드리스 이어폰"}
# {"vocab": "삼성 센스"}
# {"vocab": "빌링햄"}
# {"vocab": "PT750UD"}
# {"vocab": "Z145 케녹스 Z145"}
# {"vocab": "M 2 NVMe디스플레"}
# {"vocab": "금강제화"}
# {"vocab": "12 H410M"}
# {"vocab": "조위기어 za12"}
# {"vocab": "유디아 유디아 Look 230"}
# {"vocab": "H81보드"}
# {"vocab": "walz"}
# {"vocab": "리코 GR3"}
# {"vocab": "코오롱"}
# {"vocab": "제스파"}
# {"vocab": "btv"}
# {"vocab": "엑토 카드리더"}
# {"vocab": "16kg액티브워시액티브워시"}
# {"vocab": "망고 M54250 초미니 I5"}
# {"vocab": "COB"}
# {"vocab": "PS 10A"}
# {"vocab": "기가바이트 B550M GAMING"}
# {"vocab": "전자식카메라"}
# {"vocab": "싸이언폴더폰"}
# {"vocab": "브이펄스"}
# {"vocab": "드폴리오"}
# {"vocab": "LG 디오스830L"}
# {"vocab": "e7470"}
# {"vocab": "인천주안"}
# {"vocab": "엡손필름스캐너"}
# {"vocab": "메이플 스타2"}
# {"vocab": "lg 유플러스"}
# {"vocab": "LG엘지"}
# {"vocab": "13kgDD"}
# {"vocab": "애플케어플러스O"}
# {"vocab": "8GBX2"}
# {"vocab": "기가바이트 어"}
# {"vocab": "제니트 122 S"}
# {"vocab": "인원에어컨"}
# {"vocab": "캐논 5d mark3"}
# {"vocab": "S9 64G"}
# {"vocab": "스벅"}
# {"vocab": "성정품데스크탑"}
# {"vocab": "팬택앤큐리텔p1"}
# {"vocab": "SM T975"}
# {"vocab": "TV모니터"}
# {"vocab": "비비타"}
# {"vocab": "afl t"}
# {"vocab": "N971 미러블랙"}
# {"vocab": "동영상자동플레이어"}
# {"vocab": "노리F폰"}
# {"vocab": "스피"}
# {"vocab": "HP564XL"}
# {"vocab": "티피"}
# {"vocab": "뱅엔울룹슨 e8 sport"}
# {"vocab": "뮤조1"}
# {"vocab": "ViewZ IP HD LED 모니터"}
# {"vocab": "컴퓨터 i7 4770 i7"}
# {"vocab": "노트북"}
# {"vocab": "아이서스"}
# {"vocab": "ec3 c"}
# {"vocab": "서피스 프로5 i5"}
# {"vocab": "LG lp4500"}
# {"vocab": "인터넷 폰"}
# {"vocab": "블랙샤크 V2 Pro"}
# {"vocab": "아수스브랜드"}
# {"vocab": "축 토체프"}
# {"vocab": "빅보스 PWA 511U"}
# {"vocab": "갤럭시탭 a6 10 1 With S Pen p585 LTE"}
# {"vocab": "LG 50인치"}
# {"vocab": "빈티지 리시버"}
# {"vocab": "로지텍G1"}
# {"vocab": "아이맥액정인버터"}
# {"vocab": "애니콜 2G"}
# {"vocab": "Wi Fi 6"}
# {"vocab": "ILFORD PANF 50 35mm"}
# {"vocab": "립컴퓨터"}
# {"vocab": "칸토"}
# {"vocab": "픽셀 C"}
# {"vocab": "갤럭시탭 s7 LTE"}
# {"vocab": "LG15N53"}
# {"vocab": "VGA MX150"}
# {"vocab": "34LF640R"}
# {"vocab": "텐키리스 키보드"}
# {"vocab": "이이패드"}
# {"vocab": "플"}
# {"vocab": "갤럭시 탭 A 10 1"}
# {"vocab": "wa15j6550ks"}
# {"vocab": ",조립컴퓨터"}
# {"vocab": "워치4 하이브리드레더 S M"}
# {"vocab": "미러리스 m100"}
# {"vocab": "BRAMS S3500"}
# {"vocab": "s편의점"}
# {"vocab": "Model HP Probook 4540s"}
# {"vocab": "빈티지스피커"}
# {"vocab": "미놀타 AF S"}
# {"vocab": "LED E2050T"}
# {"vocab": "터치스타폰"}
# {"vocab": "iokhan"}
# {"vocab": "화상 전화기"}
# {"vocab": "듀얼 그래픽카드"}
# {"vocab": "아그파 셀렉트론"}
# {"vocab": "순토3"}
# {"vocab": "NK908RB"}
# {"vocab": "매직키보드12"}
# {"vocab": "500만 화소폰"}
# {"vocab": "확장키보드 2"}
# {"vocab": "IM U700S"}
# {"vocab": "와인스마트폰"}
# {"vocab": "삼성 360 pen"}
# {"vocab": "엑토 레트로 블루투스 키보드"}
# {"vocab": "스마트 tv"}
# {"vocab": "2560x1600 WQXGA DCI P3 99 IPS"}
# {"vocab": "펜탁스 ZOOM 7027"}
# {"vocab": "NEXT MHL110VS"}
# {"vocab": "레이져팩스복합기"}
# {"vocab": "블루투스 무선충전"}
# {"vocab": "산레모 베네치아 디럭스"}
# {"vocab": "shw a175s"}
# {"vocab": "인강줌"}
# {"vocab": "알파"}
# {"vocab": "5d mark2"}
# {"vocab": "젠북 UX310U"}
# {"vocab": "벤투스2팬 1070"}
# {"vocab": "ssd500"}
# {"vocab": "와"}
# {"vocab": "블루투스 이어셋"}
# {"vocab": "야시카 FR"}
# {"vocab": "NT300V5A"}
# {"vocab": "제이탭m"}
# {"vocab": "Haylou LS02"}
# {"vocab": "로지텍 G304 Hero"}
# {"vocab": "오피"}
# {"vocab": "플렉스알파 15인치"}
# {"vocab": "ms 550"}
# {"vocab": "라심발리 카사디오"}
# {"vocab": "8핀 충전기"}
# {"vocab": "요가2"}
# {"vocab": "스텝스컬쳐2"}
# {"vocab": "컴팩트카메라"}
# {"vocab": "LG 트롬 워시타워"}
# {"vocab": "이세탁기"}
# {"vocab": "CYON Chocolate"}
# {"vocab": "CANON 5000"}
# {"vocab": "서든 피파 오딘"}
# {"vocab": "노란색"}
# {"vocab": "워치4 44"}
# {"vocab": "LED 모니터"}
# {"vocab": "SLT 7080BT"}
# {"vocab": "니콘 85 8D"}
# {"vocab": "거치폰"}
# {"vocab": "엘지 클래식"}
# {"vocab": "SPH S1350"}
# {"vocab": "N971 블랙"}
# {"vocab": "에어 m1"}
# {"vocab": "4 MSI"}
# {"vocab": "KORINA 40mm f2"}
# {"vocab": "매직마우스"}
# {"vocab": "wifi 스페이스그레이애플펜슬"}
# {"vocab": "DSLR D50"}
# {"vocab": "SRT75HWPFB"}
# {"vocab": "BNC"}
# {"vocab": "아이폰8플러스"}
# {"vocab": "블랙"}
# {"vocab": "드코"}
# {"vocab": "키티카메라"}
# {"vocab": "마닉 500W"}
# {"vocab": "Canon EOS M5"}
# {"vocab": "그립소니"}
# {"vocab": "인켈 2"}
# {"vocab": "21300"}
# {"vocab": "1,2"}
# {"vocab": "Eos850"}
# {"vocab": "EPSON 엡손 L4150"}
# {"vocab": "ASRock H 81M GDS"}
# {"vocab": "애플워치 밴드"}
# {"vocab": "인공위성"}
# {"vocab": "LM Y110L"}
# {"vocab": "아이맥 2015late"}
# {"vocab": "3 5 AUX 이어팟"}
# {"vocab": "아이폰6S"}
# {"vocab": "FINO 145S"}
# {"vocab": "Canon EOS 10D"}
# {"vocab": "아이노비아"}
# {"vocab": "p115b"}
# {"vocab": "니콘코리아"}
# {"vocab": "밥말리"}
# {"vocab": "반주기모니터"}
# {"vocab": "학교원격수업용컴퓨터"}
# {"vocab": "xo v1"}
# {"vocab": "뱅엔올룹슨 B O beolab8000"}
# {"vocab": "인이어"}
# {"vocab": "35인치 와이드 울트라 모니터"}
# {"vocab": "곡"}
# {"vocab": "위니아 스탠드"}
# {"vocab": "클라쎄 투도어"}
# {"vocab": "스포츠워치"}
# {"vocab": "붐붐폰"}
# {"vocab": "OK 2000"}
# {"vocab": "체리 G80 3000S"}
# {"vocab": "f100"}
# {"vocab": "갤럭시탭 10 1 SHW M480W"}
# {"vocab": "다얼유"}
# {"vocab": "건메탈"}
# {"vocab": "LG 그램 1 14ZD90p GX50k"}
# {"vocab": "안마의자 S2040"}
# {"vocab": "서든 배그 모니터"}
# {"vocab": "사각형"}
# {"vocab": "일룸"}
# {"vocab": "삼성 i5"}
# {"vocab": "렌"}
# {"vocab": "극상프로카"}
# {"vocab": "젠북15"}
# {"vocab": "아이폰6s"}
# {"vocab": "터치 모니터"}
# {"vocab": "소형냉동"}
# {"vocab": "qcy t10"}
# {"vocab": "엘지 sv 110"}
# {"vocab": "갤럭시 노트20 그레이"}
# {"vocab": "캐논 M50"}
# {"vocab": "xp"}
# {"vocab": "라이젠5 4세대 5600XMSI MAG B450M"}
# {"vocab": "포스뱅크E2 pos"}
# {"vocab": "러빗"}
# {"vocab": "카이저"}
# {"vocab": "포터블와이파이 라우터"}
# {"vocab": "폴더2S"}
# {"vocab": "하양빨강"}
# {"vocab": "MAC 매킨토시"}
# {"vocab": ",T970"}
# {"vocab": "서피스 프로 7"}
# {"vocab": "ST"}
# {"vocab": "RtX3070"}
# {"vocab": "2020맥북프로"}
# {"vocab": "f24t650"}
# {"vocab": "짱구"}
# {"vocab": "guardian"}
# {"vocab": "jaehuid"}
# {"vocab": "6941CPU"}
# {"vocab": "미니"}
# {"vocab": "하이닉스NVME"}
# {"vocab": "NVME256G HDD1TB"}
# {"vocab": "rx100 mk4"}
# {"vocab": "블루투스케이스"}
# {"vocab": "W"}
# {"vocab": "예나 공장"}
# {"vocab": "프라다"}
# {"vocab": "파워 017"}
# {"vocab": "마이크론 BX500"}
# {"vocab": "게임용PC"}
# {"vocab": "퍼플컬러"}
# {"vocab": "k200"}
# {"vocab": "랜"}
# {"vocab": "GIGABYTE GA B250M"}
# {"vocab": "SPH W4450"}
# {"vocab": "i5 7500그래픽카드"}
# {"vocab": "튀김기"}
# {"vocab": "Apple watch7"}
# {"vocab": "321 PRO"}
# {"vocab": "라이젠 5 3600 6 core"}
# {"vocab": "라이젠 R7 5700G"}
# {"vocab": "Supreme x B O Beo play"}
# {"vocab": "광명시"}
# {"vocab": "중고모니터"}
# {"vocab": "어프로치 S62 블랙"}
# {"vocab": "HP OMEN 27i"}
# {"vocab": "블루컬러"}
# {"vocab": "E3 1230v2 i7 3770"}
# {"vocab": "아이폰8레드"}
# {"vocab": "34LB640R"}
# {"vocab": "245뮤직"}
# {"vocab": "DocuPrint C4350 A3"}
# {"vocab": "G Skill RGB DDR4"}
# {"vocab": "63키보드"}
# {"vocab": "6코어12쓰레드"}
# {"vocab": "휴라이즈"}
# {"vocab": "헤레시4"}
# {"vocab": "아이패드 에어2 에어3"}
# {"vocab": "인텍앤컴퍼니"}
# {"vocab": "IPQ 2740 QHD 165HZ"}
# {"vocab": "브라운저울"}
# {"vocab": "PL2W"}
# {"vocab": "jamo av 스피커"}
# {"vocab": "LG 65LB5200"}
# {"vocab": "갤럭시A31"}
# {"vocab": "리디북스 페이퍼 프로"}
# {"vocab": "M350"}
# {"vocab": "옥스포드"}
# {"vocab": "랩탑"}
# {"vocab": "라이젠1700"}
# {"vocab": "미녹스35GT"}
# {"vocab": "스나이퍼 카메라"}
# {"vocab": "레더 스마트커"}
# {"vocab": "갤럭시S2"}
# {"vocab": "스포매틱 필름카메라"}
# {"vocab": "NT930QCA"}
# {"vocab": "미놀타 프리덤 텔레"}
# {"vocab": "블루투스 무선 스피커"}
# {"vocab": "그램17 17ZD90P"}
# {"vocab": "라이젠4350G"}
# {"vocab": "sh150"}
# {"vocab": "코어i9 10세대 10900K"}
# {"vocab": "정격750W 80"}
# {"vocab": "p555"}
# {"vocab": "배그 GTX 1060"}
# {"vocab": "서든 피파 서든"}
# {"vocab": "큐브모양"}
# {"vocab": "2014 VP 맥북"}
# {"vocab": "사운드드럼"}
# {"vocab": "DSLR EOS 600D"}
# {"vocab": "Japan"}
# {"vocab": "썬더볼트4"}
# {"vocab": "EOS 5D Mark4"}
# {"vocab": "RX100 III"}
# {"vocab": "포터블라디오CD"}
# {"vocab": "그랑데 통버블"}
# {"vocab": "피아톤무선헤드폰"}
# {"vocab": "롤 서든"}
# {"vocab": "핸드 마이크"}
# {"vocab": "O서울"}
# {"vocab": "브라켓 N61 05685A 2"}
# {"vocab": "MS오피스서피스고"}
# {"vocab": "G402"}
# {"vocab": "신도리코 D401"}
# {"vocab": "맥북에어 13inch"}
# {"vocab": "17인치 1070 i7"}
# {"vocab": "DELLOptiplex7040"}
# {"vocab": "ad280"}
# {"vocab": "카오스큐브"}
# {"vocab": "드라이버"}
# {"vocab": "펜타블릿"}
# {"vocab": "Intel R Co"}
# {"vocab": "Nikon SB 400"}
# {"vocab": "갤럭시탭A7 64G LTE 10 4 T505"}
# {"vocab": "삼성코비폴더폰"}
# {"vocab": "크 프린터"}
# {"vocab": "jbl 20"}
# {"vocab": "Minolta"}
# {"vocab": "R6"}
# {"vocab": "G패드"}
# {"vocab": "HP OFFICEJET PRO 9010"}
# {"vocab": "삼성갤럭시탭A 8 0"}
# {"vocab": "삼성스탠드티비자"}
# {"vocab": "V28UE M"}
# {"vocab": "탄노이 식세스 613 스피커"}
# {"vocab": "의정부"}
# {"vocab": "고프로 히어로8"}
# {"vocab": "OKPOS ZED5"}
# {"vocab": "다넨즈"}
# {"vocab": "레이저 블랙위도우 토너먼트 에디션"}
# {"vocab": "i5 6600 rx570"}
# {"vocab": "실버 102"}
# {"vocab": "Think Pad"}
# {"vocab": "RWH101"}
# {"vocab": "소니A55 N50"}
# {"vocab": "4K"}
# {"vocab": "k300 파워 스피커"}
# {"vocab": "프로젝트폰"}
# {"vocab": "LG 77인치"}
# {"vocab": "델 p2419h"}
# {"vocab": "삼성인버터"}
# {"vocab": "LG통돌이"}
# {"vocab": "도킹스피커"}
# {"vocab": "A11"}
# {"vocab": "크리스탈키보드"}
# {"vocab": "황축"}
# {"vocab": "SSD128 HDD1000"}
# {"vocab": "나이키 스타라이트"}
# {"vocab": "다이나택 8000SL"}
# {"vocab": "Msi"}
# {"vocab": "삼성 10 15"}
# {"vocab": "티아티오"}
# {"vocab": "글래"}
# {"vocab": "야시카 mf 1"}
# {"vocab": "M6"}
# {"vocab": "4호선"}
# {"vocab": "UHD 스마트TV"}
# {"vocab": "미녹스 35GT"}
# {"vocab": "앤디워홀 필름 카메라"}
# {"vocab": "GIGABYTE AORUS FI25F"}
# {"vocab": "독수리"}
# {"vocab": "sf104a"}
# {"vocab": "삼성갤럭시와이드5"}
# {"vocab": "아이패드프로1"}
# {"vocab": "ip Time"}
# {"vocab": "노트북 플러스2 NT550XDA XC59G"}
# {"vocab": "슈퍼스피드"}
# {"vocab": "WF21T6300KV"}
# {"vocab": "S S D SSD"}
# {"vocab": "스마트워치"}
# {"vocab": "LG i7 지포스 GT"}
# {"vocab": "젝시믹스 그립톡"}
# {"vocab": "AAAA 23"}
# {"vocab": "메모리카드"}
# {"vocab": "D11"}
# {"vocab": ",검정"}
# {"vocab": "블랙샤크 V2 PRO"}
# {"vocab": "큐닉스 큐닉스 QX2424 144 CURVED D VA"}
# {"vocab": "캐논마운트"}
# {"vocab": "폴로라이드 랜즈"}
# {"vocab": "엘지 UHD Smart TV 75UN6970"}
# {"vocab": "EQ 노"}
# {"vocab": "A520"}
# {"vocab": "16gx2"}
# {"vocab": "R9 5900X"}
# {"vocab": "키티폰"}
# {"vocab": "일반스피커"}
# {"vocab": "흰불빛 블랙"}
# {"vocab": "갤탭 s7 wifi"}
# {"vocab": "인켈 오디오"}
# {"vocab": "로지텍 G PRO X"}
# {"vocab": "브람스 플레이비 미니 마사지체어"}
# {"vocab": "일포드"}
# {"vocab": "shw a200s"}
# {"vocab": "램16기가 1060 i5 ssd256"}
# {"vocab": "asus vg248qg"}
# {"vocab": "Wi Fi 5"}
# {"vocab": "HIS RX560 4G"}
# {"vocab": "k120"}
# {"vocab": "nikkor"}
# {"vocab": "매직홀 W830"}
# {"vocab": "애플펜스2"}
# {"vocab": "삼페인골드"}
# {"vocab": "msi gt62vr 7rd"}
# {"vocab": "i5 11400f"}
# {"vocab": "L240"}
# {"vocab": "블루투스 키보드"}
# {"vocab": "와피데일"}
# {"vocab": "타블"}
# {"vocab": "크레"}
# {"vocab": "에어팟프"}
# {"vocab": "앱코헤그셋"}
# {"vocab": "K2"}
# {"vocab": "갤럭시워치4클래식"}
# {"vocab": "미놀타 AF C"}
# {"vocab": "220V405"}
# {"vocab": "V9100"}
# {"vocab": "얼라이드"}
# {"vocab": "현아이디어"}
# {"vocab": "미쓰비시"}
# {"vocab": "아이패드프로 2세대 10 5 셀롤러"}
# {"vocab": "소닉폰"}
# {"vocab": "엘지트윈워시세탁기"}
# {"vocab": "viewsync"}
# {"vocab": "BTK 01"}
# {"vocab": "sch w580"}
# {"vocab": "SCH B890"}
# {"vocab": "4포트 허브 키보드"}
# {"vocab": "처폰"}
# {"vocab": "LC32JG50QQK"}
# {"vocab": "GeForce GTX 1080"}
# {"vocab": "i3 5005U"}
# {"vocab": "씽크패드 T"}
# {"vocab": "인텔 코어 TM i7 10700"}
# {"vocab": "준 sph v3000"}
# {"vocab": "플렉스2 NT950QDZ G51AZ"}
# {"vocab": "시모넬리아피아2"}
# {"vocab": "CTL 672"}
# {"vocab": "서든 피파 롤4"}
# {"vocab": "ssd128gssd"}
# {"vocab": "애플펜슬 1 랩씨"}
# {"vocab": "비스포크 RF85T9013AP"}
# {"vocab": "DSPE 053F"}
# {"vocab": "김치 냉장고"}
# {"vocab": "Land Camera Model 150"}
# {"vocab": "그램 16ZD90P GX56K"}
# {"vocab": "rgb로얄실버cl16 ddr4"}
# {"vocab": "애플워치 se"}
# {"vocab": "12900KFASUS"}
# {"vocab": "mb"}
# {"vocab": "35mm F1 8"}
# {"vocab": "HR T3 omega"}
# {"vocab": "수디오 펨"}
# {"vocab": "버미어라이젠"}
# {"vocab": "Ef 마운트"}
# {"vocab": "Y110"}
# {"vocab": "미놀타 SR505"}
# {"vocab": "제네럴 일랙트릭"}
# {"vocab": "셀롤러"}
# {"vocab": "AUTOMATIC 100"}
# {"vocab": "니콘 AD 3"}
# {"vocab": "lg lv7500"}
# {"vocab": "인스탁스11"}
# {"vocab": "미니엠프"}
# {"vocab": "현대큐리텔 DD101"}
# {"vocab": "lg65"}
# {"vocab": "D40X"}
# {"vocab": "zm500 leVGA"}
# {"vocab": "후지필름미니 25"}
# {"vocab": "SK 블랙실버"}
# {"vocab": "미드나잇 그레이"}
# {"vocab": "애니콜 SPH W8350매직홀폰"}
# {"vocab": "5핀시거잭"}
# {"vocab": "TK"}
# {"vocab": "britz"}
# {"vocab": "AUDIO"}
# {"vocab": "zumy 120"}
# {"vocab": "삼성무선마우스"}
# {"vocab": "올림푸스EP1"}
# {"vocab": "스페이스 그레이애케플"}
# {"vocab": "도봉로"}
# {"vocab": "LG전자 2021 그램15 15ZD95N GX56K"}
# {"vocab": "활기스아이폰11"}
# {"vocab": "K1"}
# {"vocab": "bcs700"}
# {"vocab": "sph w2700"}
# {"vocab": "캐논EOS 마크4"}
# {"vocab": "아몰래드3D폰"}
# {"vocab": "샐러드냉장고"}
# {"vocab": "와이즈모던"}
# {"vocab": "블렉라벨 19KG"}
# {"vocab": "야마카시모니터"}
# {"vocab": "efs 18 55"}
# {"vocab": "흑"}
# {"vocab": "Ncore"}
# {"vocab": "미러리스 eos m10"}
# {"vocab": "LEICA MINI ZOOM"}
# {"vocab": "에이서 xv272u"}
# {"vocab": "인텔HD 5200"}
# {"vocab": "i7 9700Frtx 2060"}
# {"vocab": "S20플러스"}
# {"vocab": "아이폰x"}
# {"vocab": "K840"}
# {"vocab": "갤럭시워치 3"}
# {"vocab": "하만카돈고플레이미니"}
# {"vocab": "네이비 슈퍼루브"}
# {"vocab": "Newsync B245H"}
# {"vocab": "인스턴트 카메라"}
# {"vocab": "갤럭시북 NT750XDA KC58S"}
# {"vocab": "대형블루투스 스피커"}
# {"vocab": "43인치QLED"}
# {"vocab": "에이건 Agon 271QG"}
# {"vocab": "m38"}
# {"vocab": "갤럭시워치 46mm r805"}
# {"vocab": "니콘 카메라플래쉬 SB 500"}
# {"vocab": "삼성전자50인치"}
# {"vocab": "Windows 10 Pro"}
# {"vocab": "s7 fe"}
# {"vocab": "씽크패드 T460 i5"}
# {"vocab": "무선게이밍"}
# {"vocab": "SM N935S"}
# {"vocab": "250기가그래픽카드"}
# {"vocab": "AORUS K9 RGB Fusion"}
# {"vocab": "니콘 FM"}
# {"vocab": "AORUS K9"}
# {"vocab": "고해상도"}
# {"vocab": "쿨픽스A10"}
# {"vocab": "z6 2 35 8"}
# {"vocab": "350D"}
# {"vocab": "아이패드 에어2 64gb wifi"}
# {"vocab": "mini"}
# {"vocab": "xl2411p"}
# {"vocab": "CANU s1000"}
# {"vocab": "TP9000"}
# {"vocab": "마샬 억스브릿지"}
# {"vocab": "폴드"}
# {"vocab": "테그호이어"}
# {"vocab": "오디오메카"}
# {"vocab": "MS Office 퍼스널 365"}
# {"vocab": "올림푸스 오토 일렉트로 셋"}
# {"vocab": "갤럭시탭S7 FE wi fi"}
# {"vocab": "EOS M50 15"}
# {"vocab": "8K QLED"}
# {"vocab": "LP"}
# {"vocab": "우퍼스퍼커"}
# {"vocab": "계산로"}
# {"vocab": "DCR VX 2000"}
# {"vocab": "XCANVAS"}
# {"vocab": "12GB스톰 X 듀얼 OC LHR"}
# {"vocab": "갤럭시S0"}
# {"vocab": "AFX PANORAMA"}
# {"vocab": "레노버탭 스마트 M10FHDPLUS TB X606F"}
# {"vocab": "LG Lu9000"}
# {"vocab": "맥북에어 M1 512"}
# {"vocab": "UETOOTH SPEAKER SLC 115"}
# {"vocab": "TFG ARF 게이트론"}
# {"vocab": "그램15 터치스크린"}
# {"vocab": "ANAMTV"}
# {"vocab": "전자피아노"}
# {"vocab": "하스웰 i3"}
# {"vocab": "RTX3060 T"}
# {"vocab": "휴"}
# {"vocab": "UHD 커브드 TV"}
# {"vocab": "디지털사진프레임"}
# {"vocab": "라데온그래픽RAM"}
# {"vocab": "드리미 v11"}
# {"vocab": "소니fe"}
# {"vocab": "L6400DWDCP"}
# {"vocab": "삼성 SPA NKG2CUB"}
# {"vocab": "shw a200s a200k"}
# {"vocab": "lg lu9400"}
# {"vocab": "쿼드스레드 GTA5"}
# {"vocab": "400D"}
# {"vocab": "Crucial BX500"}
# {"vocab": "쥬얼그립"}
# {"vocab": "기가폰 스피커"}
# {"vocab": "ASUS TUF 3080 LHR"}
# {"vocab": "삼성 Q9500"}
# {"vocab": "후지카 싱글 8 p300"}
# {"vocab": "OM D E M5"}
# {"vocab": "고장TV"}
# {"vocab": "엡손 570w"}
# {"vocab": "야시카 일렉트로"}
# {"vocab": "갤럭시워치 44mm 액티브2 골드"}
# {"vocab": "등불스피커"}
# {"vocab": "sk2g 657"}
# {"vocab": "아르파커피머신"}
# {"vocab": "rtx 3060ti"}
# {"vocab": "계양구중고냉장고"}
# {"vocab": "Full HD RAM"}
# {"vocab": "써드파티 링크 브레이슬릿"}
# {"vocab": "ROG Z11 ITX CASE"}
# {"vocab": "갤럭시 워치 액티브2 스댕"}
# {"vocab": "intel R HP Graphis 30004"}
# {"vocab": "와이파이 스페이스 그레이"}
# {"vocab": "무선이어폰"}
# {"vocab": "FHD i5"}
# {"vocab": "럭스만"}
# {"vocab": "아이락스"}
# {"vocab": "갤럭시북 이온 NT930XCJ K58"}
# {"vocab": "R BLACK"}
# {"vocab": "samsungb2b"}
# {"vocab": "갤럭시노트10 5G N971"}
# {"vocab": "커스텀키보"}
# {"vocab": "40mm Nike"}
# {"vocab": "캐논 EOS 5D Mark 2 24 70"}
# {"vocab": "울트라기어 15G880 SD70K"}
# {"vocab": "800D"}
# {"vocab": "디케이 미니에어"}
# {"vocab": "LG LED ISP"}
# {"vocab": "L35"}
# {"vocab": "반세탁기"}
# {"vocab": "클라셰"}
# {"vocab": "바디5d mark4"}
# {"vocab": "애쉬우드"}
# {"vocab": "오로라 곰돌이"}
# {"vocab": "오버워치게임"}
# {"vocab": "아이패드 프로3세대 11 wifi 256 스그"}
# {"vocab": "T1"}
# {"vocab": "lg노트북 15n540 i7"}
# {"vocab": "야시카AUTO FOCUS"}
# {"vocab": "메리디안"}
# {"vocab": "GTX970 4G GTX1060"}
# {"vocab": "콜롬스피커"}
# {"vocab": "77GXP"}
# {"vocab": "GH5 마이크로포서드 12035"}
# {"vocab": "GTX 1660ti"}
# {"vocab": "인스탁스70화이트"}
# {"vocab": "mk2"}
# {"vocab": "필코 마체스터치2"}
# {"vocab": "폰케이스"}
# {"vocab": "메루카리"}
# {"vocab": "jbl horizon2"}
# {"vocab": "삼성 기어 S3 프론티어"}
# {"vocab": "에이에스"}
# {"vocab": "imac"}
# {"vocab": "SPA NKG1CUB"}
# {"vocab": "Inspiron15 5501"}
# {"vocab": "CURVED"}
# {"vocab": "SSD128 HDD750"}
# {"vocab": "샤벳"}
# {"vocab": "802 11ax"}
# {"vocab": "비보북 X507UA EJ503T"}
# {"vocab": "3 5 AUX 이어팟 잰더"}
# {"vocab": "a1398"}
# {"vocab": "배앤올룹슨"}
# {"vocab": "ONKYO TXSR577"}
# {"vocab": "V300"}
# {"vocab": "엠메스트"}
# {"vocab": "울트라와이드 34UM88C"}
# {"vocab": "8GBGPU"}
# {"vocab": "카트리지"}
# {"vocab": "그라파이트"}
# {"vocab": "미니 무드 램프"}
# {"vocab": "UN 55 MU 7500 FXKR"}
# {"vocab": "갤럭시 액티브태블릿"}
# {"vocab": "gf9"}
# {"vocab": "그린256"}
# {"vocab": "E995"}
# {"vocab": "한효주디카"}
# {"vocab": "Bluetooth Profile Bluetooth"}
# {"vocab": "af zoom"}
# {"vocab": "캐녹스 140 QS"}
# {"vocab": "씨메05"}
# {"vocab": "커세어수냉 커세 h150i rgb pro 360"}
# {"vocab": "브리츠 BA C1"}
# {"vocab": "애플워치 브레이드"}
# {"vocab": "16GGTX 960"}
# {"vocab": "프포스기"}
# {"vocab": "z flip3"}
# {"vocab": "갤럭시워치 SM R815N"}
# {"vocab": "수디오 니오 블랙"}
# {"vocab": "MlT D115L"}
# {"vocab": "펜티엄브로드웰"}
# {"vocab": "삼성전자TV"}
# {"vocab": "델 인스피론 15 5547 i5 4210U"}
# {"vocab": "묠니르"}
# {"vocab": "코시 아머"}
# {"vocab": "노트10 플러스"}
# {"vocab": "테블릿PC"}
# {"vocab": "펜탁스 줌 90 Zoom 90"}
# {"vocab": "억스브릿지보이스"}
# {"vocab": "라이트닝 C"}
# {"vocab": "증폭스피커"}
# {"vocab": "지포스 롤 피파4"}
# {"vocab": "spm"}
# {"vocab": "TFT 큐닉스"}
# {"vocab": "세룰러 애플펜슬"}
# {"vocab": "턴테이"}
# {"vocab": "캐리어 인버터 에어컨"}
# {"vocab": "num"}
# {"vocab": "G781"}
# {"vocab": "애니젠"}
# {"vocab": "p mini"}
# {"vocab": "ko"}
# {"vocab": "스카이듀크폰im s330"}
# {"vocab": "i5 3570 B75 GTX750Ti"}
# {"vocab": "폴더폰"}
# {"vocab": "m 2 RX 570"}
# {"vocab": "다이나믹마이크"}
# {"vocab": "모토로라 BX40 v9m v9mle"}
# {"vocab": "CLX 3160"}
# {"vocab": "5900x"}
# {"vocab": "레이져 블레이드 15"}
# {"vocab": "RC400"}
# {"vocab": "XF16"}
# {"vocab": "미놀타 프리덤비스타 P s"}
# {"vocab": "형님마우스"}
# {"vocab": "3Df9c1e2b3f48e1617eeccd3fce0608467f1ddf8da"}
# {"vocab": "145만원75UM8070"}
# {"vocab": ",전원"}
# {"vocab": "8G GTX650"}
# {"vocab": "중고포스기"}
# {"vocab": "스댕45mm"}
# {"vocab": "A3951"}
# {"vocab": "U32R590"}
# {"vocab": "태광 아너 TSP 4300"}
# {"vocab": "엔비"}
# {"vocab": "뚜거몰중고가전마트"}
# {"vocab": "리안리 유니펜"}
# {"vocab": "고성능컴윈도우10"}
# {"vocab": "햅시"}
# {"vocab": "GTG Full HD"}
# {"vocab": "sf"}
# {"vocab": "토탈시그니처"}
# {"vocab": "울트라와이드모니터 34uc98"}
# {"vocab": "27MN430HWM"}
# {"vocab": "플레"}
# {"vocab": "스그 배터리"}
# {"vocab": "소니 16mm F2 8렌즈"}
# {"vocab": "탄노이 아덴"}
# {"vocab": "제이웍스"}
# {"vocab": "라데온540"}
# {"vocab": "Lenovo ThinkPad E14"}
# {"vocab": "정격파워 H110보드"}
# {"vocab": "MSI 1660 ARMOR"}
# {"vocab": "LG트롬드럼세탁기"}
# {"vocab": "PG K6000V"}
# {"vocab": "아이패드 프로 5세대 M1 wifi"}
# {"vocab": "바코드 리딩기"}
# {"vocab": "MSI 올인원PC"}
# {"vocab": "ope"}
# {"vocab": "uhd ledtv"}
# {"vocab": "갤럭시Z플립 256G"}
# {"vocab": "LG OLED48C1KNB"}
# {"vocab": "이퀄라"}
# {"vocab": "Retina"}
# {"vocab": "이동카"}
# {"vocab": "t805"}
# {"vocab": "CUTMAN"}
# {"vocab": "Arc 아크 블루투스"}
# {"vocab": "장"}
# {"vocab": "맞은편"}
# {"vocab": "아이패드에어2"}
# {"vocab": "갤럭시탭s7 fe"}
# {"vocab": "무선 블루투스 마이크"}
# {"vocab": "등피처폰"}
# {"vocab": "tsx 80"}
# {"vocab": "LG XCANVAS"}
# {"vocab": "소니a5000미러리스 카메라"}
# {"vocab": "플랙"}
# {"vocab": "holeic"}
# {"vocab": "T450"}
# {"vocab": "코니카"}
# {"vocab": "뷰게라"}
# {"vocab": "켄코"}
# {"vocab": "플라즈마"}
# {"vocab": "이엠템"}
# {"vocab": "핏빗"}
# {"vocab": "니콘J1"}
# {"vocab": "BA R9"}
# {"vocab": "웨스턴 일렉트릭사"}
# {"vocab": "LG UHD TV"}
# {"vocab": "체리 g80 3000s"}
# {"vocab": "기가지니 LTE2"}
# {"vocab": "고속충전기"}
# {"vocab": "UHD 스마트 TV"}
# {"vocab": "GIGA A320M"}
# {"vocab": "VEGA 77i"}
# {"vocab": "i5 10600kf"}
# {"vocab": "블랙색"}
# {"vocab": "블루콤"}
# {"vocab": "인텔i7 8700 cpu"}
# {"vocab": "애플워치 시리즈6"}
# {"vocab": "11 H410M"}
# {"vocab": "공관"}
# {"vocab": "갤럭시워치4 46미리 클래식"}
# {"vocab": "윈10pro"}
# {"vocab": "삼성애니콜 SCH W360"}
# {"vocab": "실버 에플 팬슬"}
# {"vocab": "CPU 10100"}
# {"vocab": "sh100"}
# {"vocab": "데미 하프 S"}
# {"vocab": "SCX 1360"}
# {"vocab": "수동필름카메라G3"}
# {"vocab": "리코 오토하프se"}
# {"vocab": "lg 20oled 20c9 20bna"}
# {"vocab": "위니아 딤채 김치냉장고"}
# {"vocab": "블루투스 알람 스피커"}
# {"vocab": "2020맥북프로m1"}
# {"vocab": "LAMINATOR 6R"}
# {"vocab": "래건조"}
# {"vocab": "Webcam hdmi"}
# {"vocab": "axp55"}
# {"vocab": "Nike"}
# {"vocab": "디엠비"}
# {"vocab": "PUA"}
# {"vocab": "저스트인테크"}
# {"vocab": "G7xmark2"}
# {"vocab": "33mm f3 5"}
# {"vocab": "씽크패드 X1"}
# {"vocab": "LN40R81BD"}
# {"vocab": "m518"}
# {"vocab": "EOS M10"}
# {"vocab": "아이패드프로5세대 wi fi"}
# {"vocab": "HP Z800 X5675"}
# {"vocab": "스텐드형 55"}
# {"vocab": "포스본"}
# {"vocab": "iR2022K A4,A3"}
# {"vocab": "f 1 8 F 10 5 27 5mmFujica Single 8 P300"}
# {"vocab": "VGA RTX3060TI"}
# {"vocab": "호핀"}
# {"vocab": "B W WEDGE"}
# {"vocab": "g패드"}
# {"vocab": "펜탁스 줌105"}
# {"vocab": "라이카 d lux7"}
# {"vocab": "야시논"}
# {"vocab": "z820"}
# {"vocab": "V15FPB"}
# {"vocab": "포토샆CS6아크로벳 리더 DC"}
# {"vocab": "LG 헬로비전"}
# {"vocab": "니콘마운트"}
# {"vocab": "레이저 블랙위도우v3 pro"}
# {"vocab": "JBL VTX S28 G28 크라운"}
# {"vocab": "500GB"}
# {"vocab": "O10"}
# {"vocab": "페"}
# {"vocab": "블루투스5"}
# {"vocab": "번톡"}
# {"vocab": "롤라이 프레고 줌"}
# {"vocab": "맥북에어 레티나 13인치"}
# {"vocab": "좌측"}
# {"vocab": "삼성 에어드레서"}
# {"vocab": "LG 15U560 KR5HK"}
# {"vocab": "i3 10100F GTX 960"}
# {"vocab": "archon"}
# {"vocab": "벨프린터"}
# {"vocab": "미니4"}
# {"vocab": "디지니 푸"}
# {"vocab": "제네바스피커 m"}
# {"vocab": "메인보드"}
# {"vocab": "신지모루"}
# {"vocab": "렘 16 ssd240"}
# {"vocab": "앱코 MES100"}
# {"vocab": "G5 X Mark2"}
# {"vocab": "su40dk tv"}
# {"vocab": "X4 쿼드스레드CPU"}
# {"vocab": "UN43N5020AFXKR"}
# {"vocab": "페쇄기"}
# {"vocab": "동문굿모닝힐맘시티"}
# {"vocab": "eos 300d"}
# {"vocab": "드파운드"}
# {"vocab": "갤럭시 탭S3 T820"}
# {"vocab": "아이패드5"}
# {"vocab": "wifit force 3200 cl20 ddr4"}
# {"vocab": "마그네틱"}
# {"vocab": "ex"}
# {"vocab": "고속A3복합기"}
# {"vocab": "아이패드 스마트 키보드 폴리오 11"}
# {"vocab": "로지텍 G102 Prodigy"}
# {"vocab": "워시타워"}
# {"vocab": "써멀테이크"}
# {"vocab": "LG V300"}
# {"vocab": "i7 10700"}
# {"vocab": "FR17WDA"}
# {"vocab": "테싸"}
# {"vocab": "z50"}
# {"vocab": "s7키보드"}
# {"vocab": "미놀타 미놀타xd5"}
# {"vocab": "마샬 헤드셋"}
# {"vocab": "FUJICA DL 20"}
# {"vocab": "10세대 i9 10900"}
# {"vocab": "니콘 필카 f50"}
# {"vocab": "아이폰 X 64네고 X"}
# {"vocab": "아이폰7,7 7시리즈"}
# {"vocab": "기가바이트 GTX1060"}
# {"vocab": "m1 맥북에어"}
# {"vocab": "오디오독"}
# {"vocab": "35DC"}
# {"vocab": "택포 인스탁스 미니11"}
# {"vocab": "안테나"}
# {"vocab": "pda폰"}
# {"vocab": "tv겸용모니터"}
# {"vocab": "g840 장패드"}
# {"vocab": "F710"}
# {"vocab": "로지텍G402"}
# {"vocab": "X7"}
# {"vocab": "WIFI6"}
# {"vocab": "토스오디오"}
# {"vocab": "현대올림푸스"}
# {"vocab": "연아햅틱폰"}
# {"vocab": "팬톤 TWS AIR"}
# {"vocab": "원도어"}
# {"vocab": "오리진 코어"}
# {"vocab": "미디어패드"}
# {"vocab": "Starlight8"}
# {"vocab": "디락 mk2"}
# {"vocab": "트라이"}
# {"vocab": "아반떼MD"}
# {"vocab": "스킬맨 C 850"}
# {"vocab": "35mm f3 5 Hexanon Lens Hexanon Lens"}
# {"vocab": "리코 YF 20D"}
# {"vocab": "EOS 80D"}
# {"vocab": "전기냉난방기"}
# {"vocab": "NT930XCJ K58"}
# {"vocab": "i5 8300H"}
# {"vocab": "위니아2in1"}
# {"vocab": "미놀타CAPIOJ 130S"}
# {"vocab": "갤럭시탭 Advanced2 SM T583"}
# {"vocab": "소형 냉장고"}
# {"vocab": "기가 WIFI"}
# {"vocab": "inity"}
# {"vocab": "아이맥 2009"}
# {"vocab": "WDC"}
# {"vocab": "갤럭시 버즈 프로"}
# {"vocab": "MP3"}
# {"vocab": "엑스캔버라"}
# {"vocab": "eos 500d"}
# {"vocab": "Y50 70"}
# {"vocab": "sch b540"}
# {"vocab": "로지텍mk235"}
# {"vocab": "C49RG90 C49RG90"}
# {"vocab": "32 MB25VQ"}
# {"vocab": "dsc h50"}
# {"vocab": "비와이패드1"}
# {"vocab": "i5 760 하드 SSD128 HDD500메모"}
# {"vocab": "후지필름 x t200"}
# {"vocab": "EF S"}
# {"vocab": "TUF"}
# {"vocab": "SCH 100"}
# {"vocab": "다크그레이"}
# {"vocab": "XF10"}
# {"vocab": "델 P54G i7 7560U"}
# {"vocab": "BX2335"}
# {"vocab": "화이트 컬러"}
# {"vocab": "노캔o"}
# {"vocab": "DSLR"}
# {"vocab": "햅틱아몰레드 SPH W8500"}
# {"vocab": "LG 70인치 울트라 스마트TV"}
# {"vocab": "위티6v6싱글앰프"}
# {"vocab": "MSI GS75 스틸스 슬림 경량"}
# {"vocab": "폴더폰충전기"}
# {"vocab": "양옆"}
# {"vocab": "삼성pc"}
# {"vocab": "멀티텔레 필름카메라"}
# {"vocab": "LSW420AX"}
# {"vocab": "의류건조기"}
# {"vocab": "에르메스 더블투어"}
# {"vocab": "EI 35 FXD"}
# {"vocab": "SGM 35"}
# {"vocab": "Lenovo"}
# {"vocab": "케논DSLR"}
# {"vocab": "LE01"}
# {"vocab": "보기드"}
# {"vocab": "조립"}
# {"vocab": "니콘 쿨픽스P300"}
# {"vocab": "옥션"}
# {"vocab": "오토보이텔레"}
# {"vocab": "m smartstore naver com"}
# {"vocab": "유선새"}
# {"vocab": "ESR짭플펜슬"}
# {"vocab": "코니빅미니 201"}
# {"vocab": "인텔 HD 530"}
# {"vocab": "애플 코리아"}
# {"vocab": "별내중고세탁기"}
# {"vocab": "갤럭시 탭E"}
# {"vocab": "G Pro"}
# {"vocab": "블랙 미러리스 카메라"}
# {"vocab": "raz"}
# {"vocab": "와이파이 스타라이트"}
# {"vocab": "서피스 랩탑 2"}
# {"vocab": "240파이오니아"}
# {"vocab": "DELL E170SB"}
# {"vocab": "밀"}
# {"vocab": "후지 파인픽스 S200EXR"}
# {"vocab": "마우스 로켓 콘퓨어"}
# {"vocab": "3단 미니 오디오오디오 랙"}
# {"vocab": "터틀비치 스틸600"}
# {"vocab": "용게임데스크탑"}
# {"vocab": "기가와이파이6"}
# {"vocab": "에어팟프로케이스"}
# {"vocab": "galaxyboo"}
# {"vocab": "c850"}
# {"vocab": "효도폰고3폰피처폰3G모델"}
# {"vocab": "HGP 7000H 걸리버"}
# {"vocab": "준성테크"}
# {"vocab": "사파이어"}
# {"vocab": "sk3g 827"}
# {"vocab": "LGU5615"}
# {"vocab": "맥북 에어 2020 a2179"}
# {"vocab": "AMD RADEON HD 8500 8700M"}
# {"vocab": "지포스 GTX 10"}
# {"vocab": "니콘LCD"}
# {"vocab": "모비프렌"}
# {"vocab": "블루토스"}
# {"vocab": "8GB M 2 SATA"}
# {"vocab": "LG i5"}
# {"vocab": "큐닉스"}
# {"vocab": "VIVOX 206"}
# {"vocab": "LG AI UHD TV"}
# {"vocab": "Lo co Track"}
# {"vocab": "LG U 스카이 im u540l"}
# {"vocab": "아이폰12프로실버"}
# {"vocab": "디아2 배그 롤 옵치"}
# {"vocab": "35포인트플래시"}
# {"vocab": "워존"}
# {"vocab": "갤럭시북 플렉스 NT930QCG K716A"}
# {"vocab": "아이맥 2019"}
# {"vocab": "캐리어 냉난방기"}
# {"vocab": "리시버 RX V450"}
# {"vocab": "에이튜브"}
# {"vocab": "6 i5 10400F"}
# {"vocab": "라이젠 2700 gtx 970"}
# {"vocab": "마샬 루악"}
# {"vocab": "PNY"}
# {"vocab": "lg그램형"}
# {"vocab": "S5HSCPU"}
# {"vocab": "a1493"}
# {"vocab": "펜탁스이니렌즈"}
# {"vocab": "초보카메라"}
# {"vocab": "요가스트탭"}
# {"vocab": "삼성흑백"}
# {"vocab": "폼3"}
# {"vocab": "산디스크"}
# {"vocab": "한고무"}
# {"vocab": "유선LAN"}
# {"vocab": "gtx750 gddr5"}
# {"vocab": "삼성 오디세이 게이밍"}
# {"vocab": "NVIDIA Geforce 940MX"}
# {"vocab": "아맥스 미쉘"}
# {"vocab": "75인치"}
# {"vocab": "SSD M 2 SSD"}
# {"vocab": "Ldplayer"}
# {"vocab": "갤럭시 RTX 3060 Ti D6"}
# {"vocab": "코니카bigmini201"}
# {"vocab": "CWS 150RT"}
# {"vocab": "IPF8300S"}
# {"vocab": "갤럭시북 플렉스 NT950QCG X71SA"}
# {"vocab": "갤럭시 Z폴드 블랙"}
# {"vocab": "올레드 OLEDTV"}
# {"vocab": "인버터세탁기"}
# {"vocab": "커피레이크그래픽 GTX1060"}
# {"vocab": "Leica C Lux Leather S"}
# {"vocab": "캐논프린트기"}
# {"vocab": "넥스트"}
# {"vocab": "t825"}
# {"vocab": "128G Wifi"}
# {"vocab": "턴테"}
# {"vocab": "배그 모니터"}
# {"vocab": "오펜트"}
# {"vocab": "캐논 오토보이 카메라"}
# {"vocab": "SDD"}
# {"vocab": "리버네트워크"}
# {"vocab": "하만카돈아우라"}
# {"vocab": "LG T480"}
# {"vocab": "롤PC"}
# {"vocab": "ASUS PRIME H410M K"}
# {"vocab": "애플워치 스트랩44"}
# {"vocab": "아이폰맥스"}
# {"vocab": "USB 충전"}
# {"vocab": "방수 필름 카메라"}
# {"vocab": "엄마폰"}
# {"vocab": "부비부비폴더폰"}
# {"vocab": "울트라hd"}
# {"vocab": "제우스랩 p15a"}
# {"vocab": "다운도란스"}
# {"vocab": "lg kp3000"}
# {"vocab": "삼성SM B520SL"}
# {"vocab": "owlab mr suit"}
# {"vocab": "노래방가라오케"}
# {"vocab": "아이맥 2011 27"}
# {"vocab": "코니카 NOU 135"}
# {"vocab": "NX100 20 50"}
# {"vocab": "유니쿨라"}
# {"vocab": "Hp officeJet 4650"}
# {"vocab": "지클릭커"}
# {"vocab": "고스트"}
# {"vocab": "수직형"}
# {"vocab": "아이폰 12프로맥스"}
# {"vocab": "우성토핑냉장고"}
# {"vocab": "PC3 8500s"}
# {"vocab": "라세르 테이블냉장고"}
# {"vocab": "콘지"}
# {"vocab": "그린에어4"}
# {"vocab": "아이뮤즈 스톰북 14프로"}
# {"vocab": "리더기"}
# {"vocab": "대흥 DH 1500 4"}
# {"vocab": "말기"}
# {"vocab": "XP Pen 23 8"}
# {"vocab": "CPU i5 4590"}
# {"vocab": "갤럭시탭 s2"}
# {"vocab": "카메라올림푸스EPL2"}
# {"vocab": "해리포터"}
# {"vocab": "라이젠 3600 b450"}
# {"vocab": "캐논 400d kiss Digital X"}
# {"vocab": "nt"}
# {"vocab": "갤럭시 s6 256"}
# {"vocab": "27MA92D"}
# {"vocab": "LG 퍼플"}
# {"vocab": "LG XNOTE"}
# {"vocab": "위니아 딤채"}
# {"vocab": "매직워시"}
# {"vocab": "레트로엔틱"}
# {"vocab": "갤럭시A6"}
# {"vocab": "갤럭시 탭A8 0 with S PEN sm p200"}
# {"vocab": "anc tws"}
# {"vocab": "J5"}
# {"vocab": "SSD240GVGA"}
# {"vocab": "ASUS ProArt PA32UCX 4"}
# {"vocab": "유선마이크"}
# {"vocab": "EOS 70D EF S 18 55"}
# {"vocab": "GT630하드"}
# {"vocab": "갤럭시 1060"}
# {"vocab": "Sony 쏘니 미러리스 카메라"}
# {"vocab": "갤럭시Z플립 블랙"}
# {"vocab": "마샬 스피커"}
# {"vocab": "코니카 팝 그레이"}
# {"vocab": "고냉난방기"}
# {"vocab": "싸이버펑크에디션"}
# {"vocab": "ventus 2x"}
# {"vocab": "엘지싸이언"}
# {"vocab": "삼성UN78JS9500F"}
# {"vocab": "mobile"}
# {"vocab": "산레모 베네치아"}
# {"vocab": "블렌더"}
# {"vocab": "폴라로이드카메라"}
# {"vocab": "niz micro82 EC S 45g"}
# {"vocab": "직수형 정수기"}
# {"vocab": "오픈카카오톡"}
# {"vocab": "fhd"}
# {"vocab": "미니 공유기"}
# {"vocab": "스카이 베가"}
# {"vocab": "올인원앰프스피커"}
# {"vocab": "인터넷키폰전화기"}
# {"vocab": "신폰"}
# {"vocab": "갤럭시탭 S5 10 5 SM T720"}
# {"vocab": "lg 42lw6500"}
# {"vocab": "xp pen artist 12"}
# {"vocab": "HSA12035"}
# {"vocab": "햅틱아몰레드코비폰"}
# {"vocab": "모양"}
# {"vocab": "HIFI스테레오"}
# {"vocab": "LG울트라북 13UD580 GX30K 13U580 코어 i3 HD620"}
# {"vocab": "키보드마우스"}
# {"vocab": "비츠 스노우보드"}
# {"vocab": "23인치"}
# {"vocab": "이안리플렉스"}
# {"vocab": "sch w390"}
# {"vocab": "스마트패드"}
# {"vocab": "HP 컴팩 NX7100HP compaq"}
# {"vocab": "모토로라V11"}
# {"vocab": "리틀트윈스타"}
# {"vocab": "모닝 업"}
# {"vocab": "FD ssc 50mm f1 4"}
# {"vocab": "하나시스키오스크 K 200D"}
# {"vocab": "8세대 에어"}
# {"vocab": "019"}
# {"vocab": "시모넬리"}
# {"vocab": "탑트윈 오토보이 텔레"}
# {"vocab": "서브스피커"}
# {"vocab": "EL 9950"}
# {"vocab": "엘피 온수기"}
# {"vocab": "맥북용"}
# {"vocab": "전동"}
# {"vocab": "우드폰"}
# {"vocab": "중고냉난방기"}
# {"vocab": "8587"}
# {"vocab": "인강머신"}
# {"vocab": "LG SV590"}
# {"vocab": "니콘 L35 ad2"}
# {"vocab": "PartNumber"}
# {"vocab": "17ZD95N GX56K"}
# {"vocab": "무풍"}
# {"vocab": "cpx3800"}
# {"vocab": "SK 2g 011"}
# {"vocab": "아그파 옵티마 200"}
# {"vocab": "LP C1450S"}
# {"vocab": "옴니아팝"}
# {"vocab": "GS66 Stealth 10SGS"}
# {"vocab": "좌측면"}
# {"vocab": "인스픽S"}
# {"vocab": "LG 2"}
# {"vocab": "흑백 레이져 복합기"}
# {"vocab": "갤럭시북프로 NT950XDC XL51S"}
# {"vocab": "액정"}
# {"vocab": "A1465"}
# {"vocab": "3 4채널앰프"}
# {"vocab": "WELICA W 21114"}
# {"vocab": "맥섬 HT si"}
# {"vocab": "스테레오 앰프"}
# {"vocab": "sch x120"}
# {"vocab": "TS8190"}
# {"vocab": "i7 모바일 쿼드코어"}
# {"vocab": "노브랜드"}
# {"vocab": "lsw420ax"}
# {"vocab": "32UD99"}
# {"vocab": "쉬프터"}
# {"vocab": "마이페이브아카이브"}
# {"vocab": "클루윅스 듀얼 다이나믹 인이어"}
# {"vocab": "엘지건조기"}
# {"vocab": "Coolpix A10"}
# {"vocab": "유닛트 스피커"}
# {"vocab": "와치폰"}
# {"vocab": "터치스크"}
# {"vocab": "하이브리드 인덕션"}
# {"vocab": "8만비와이패드2"}
# {"vocab": "T21 T31 T41 T51밧데리 LP E8"}
# {"vocab": "아컨플"}
# {"vocab": "갤럭시S1"}
# {"vocab": "블루문"}
# {"vocab": "아마존 파이어 HD 10"}
# {"vocab": "칠구칠육"}
# {"vocab": "갤럭시북 플렉스2 NT950QDA XC71B"}
# {"vocab": "CPU수냉쿨러"}
# {"vocab": "a5000"}
# {"vocab": "ev w100 kt 648"}
# {"vocab": "ed감성티비"}
# {"vocab": "intel Xeon W Memory"}
# {"vocab": "갤럭시 S8메모리"}
# {"vocab": "다빈치 XYZ"}
# {"vocab": "GTX1070"}
# {"vocab": "Zenbook Pro"}
# {"vocab": "LG SU410 캔디폰"}
# {"vocab": "LG UHD 4K"}
# {"vocab": "삼국지 11"}
# {"vocab": "스카이 im u560k"}
# {"vocab": "SM T735NZKHKOO"}
# {"vocab": "어이폰"}
# {"vocab": "hd"}
# {"vocab": "sk3g sc m1000"}
# {"vocab": "골리아투스 크로마"}
# {"vocab": "삼성양문형"}
# {"vocab": "i5 7300U"}
# {"vocab": "울트라와이드 21 9"}
# {"vocab": "프라다폰1 SB310"}
# {"vocab": "노트북 15 d007TX15"}
# {"vocab": "덴키리스"}
# {"vocab": "인켈 앰프"}
# {"vocab": "GTG TN 1000 1"}
# {"vocab": "550D"}
# {"vocab": "CH 510 화이트"}
# {"vocab": "EF DT970"}
# {"vocab": "A 23"}
# {"vocab": "애니샵D5"}
# {"vocab": "202117ZD90P GX50K"}
# {"vocab": "성가대마이크"}
# {"vocab": "셀룰러 카메라"}
# {"vocab": "AS 23WDLED"}
# {"vocab": "플립북13"}
# {"vocab": "AH T600 디바"}
# {"vocab": "i9 RTX3060"}
# {"vocab": "KB1 백축 텐키 블랙"}
# {"vocab": "래드색상"}
# {"vocab": "아티브9 NT910S3K"}
# {"vocab": "RC410"}
# {"vocab": "wemakeprice com"}
# {"vocab": "루끄 에어케어"}
# {"vocab": "레온 브롤스타즈"}
# {"vocab": "블리츠"}
# {"vocab": "에 썻"}
# {"vocab": "SL J1660"}
# {"vocab": "200D2"}
# {"vocab": "리코오토하프 ef 카메라"}
# {"vocab": "Nikon D5100"}
# {"vocab": "RGB"}
# {"vocab": "3Dslsl"}
# {"vocab": "브리츠"}
# {"vocab": "커세어 k70"}
# {"vocab": "소주냉동고"}
# {"vocab": "찰리브라운"}
# {"vocab": "라우드 스피커"}
# {"vocab": "i3 550하드"}
# {"vocab": "cpu i5 9400f"}
# {"vocab": "윈도우 맥"}
# {"vocab": "a s센터"}
# {"vocab": "Ultra Dual Drive Go USB Type C"}
# {"vocab": "삼성정품파워i5"}
# {"vocab": "NIKON COOLPIX 990134"}
# {"vocab": "TWS 07"}
# {"vocab": "터치뮤직"}
# {"vocab": "ad266r"}
# {"vocab": "게이밍 무선 헤드셋"}
# {"vocab": "직조선"}
# {"vocab": "Z up60"}
# {"vocab": "안드로이드 UHD TV 75P8M"}
# {"vocab": "intel core i3 2350M"}
# {"vocab": "노트3"}
# {"vocab": "러빗XP"}
# {"vocab": "아두이노 우노 R3"}
# {"vocab": "스카이 IM U210K"}
# {"vocab": "더블데크카"}
# {"vocab": "캐논 100D 탐론 SP24 70"}
# {"vocab": "파워1000W WIN10"}
# {"vocab": "레티나 디스플레"}
# {"vocab": "SK3g"}
# {"vocab": "삼성 스마트 3D Full HD LED TV"}
# {"vocab": "콕스"}
# {"vocab": "DDR4"}
# {"vocab": "라이져카"}
# {"vocab": "NVME SSD"}
# {"vocab": "올림푸스펜"}
# {"vocab": "LG천장형냉난방기"}
# {"vocab": "나이키 스타라이트 45"}
# {"vocab": "b550mortar"}
# {"vocab": "프리미어 PC 740D"}
# {"vocab": "카비레이크R"}
# {"vocab": "lexon mino"}
# {"vocab": "피코유 브이알 헤드셋"}
# {"vocab": "갤럭시북 i5"}
# {"vocab": "실버 44MM"}
# {"vocab": "차박 프로젝트"}
# {"vocab": "휴이온 캄바스프로"}
# {"vocab": "퀀텀닷 QHD VA"}
# {"vocab": "캐논 오토보이S"}
# {"vocab": "니콘FM10"}
# {"vocab": "삼성ssd250gi3"}
# {"vocab": "i7 4770 GTX1060"}
# {"vocab": "엘지휘센에어컨"}
# {"vocab": "KR시즈"}
# {"vocab": "에이메카"}
# {"vocab": "sk3g 772"}
# {"vocab": "엘지 삼성"}
# {"vocab": "FM 필름카메라"}
# {"vocab": "신품엘지인버터"}
# {"vocab": "번지"}
# {"vocab": "bixolon slp d420"}
# {"vocab": "코비카 35 BC"}
# {"vocab": "갤럭시탭s2"}
# {"vocab": "아이폰 XS 맥스"}
# {"vocab": "미놀타 sr T"}
# {"vocab": "스텐드에어컨"}
# {"vocab": "소니 1170"}
# {"vocab": "셀프 스피커"}
# {"vocab": "초전초"}
# {"vocab": "정품원도10"}
# {"vocab": "P585"}
# {"vocab": "어로스마스터"}
# {"vocab": "갤럭시탭S2 lte 9"}
# {"vocab": "HFM512GD3JX013N"}
# {"vocab": "후지 인스탁스 미니25"}
# {"vocab": "emie"}
# {"vocab": "ApplebM1"}
# {"vocab": "V27F390"}
# {"vocab": "IMK 101키보드"}
# {"vocab": "서브 tv"}
# {"vocab": "오토바이"}
# {"vocab": "SX 70"}
# {"vocab": "서피스고3"}
# {"vocab": "듀얼5"}
# {"vocab": "휴대용단말기"}
# {"vocab": "소니서비스센터"}
# {"vocab": "텍타일"}
# {"vocab": "갈축 Gtx1060 i5 6600"}
# {"vocab": "MPC2004EX"}
# {"vocab": "LG HBS PL5"}
# {"vocab": "X"}
# {"vocab": "2 3GHz14Z960 i3 6100U"}
# {"vocab": "마샬 스탠모어"}
# {"vocab": "Ideapad 700 i5 6300HQ"}
# {"vocab": "번개"}
# {"vocab": "모토뷰 MS800"}
# {"vocab": "LG그램17 i7"}
# {"vocab": "라이트 블랙"}
# {"vocab": "엘지냉장고"}
# {"vocab": "BX2250"}
# {"vocab": "비츠 스튜디오"}
# {"vocab": "a20"}
# {"vocab": "d2c2"}
# {"vocab": "i5 SSD"}
# {"vocab": "엘지티비tv"}
# {"vocab": "딤채 스탠드 인버터"}
# {"vocab": "LG G2 F320"}
# {"vocab": "우체국택배"}
# {"vocab": "키"}
# {"vocab": "GTX650Ti i5"}
# {"vocab": "15zd90n"}
# {"vocab": "DSLR NEX 3 넥스3"}
# {"vocab": "인버터 냉 난방기"}
# {"vocab": "멜론"}
# {"vocab": "코닥 vr35"}
# {"vocab": "코니카 POP EFJ"}
# {"vocab": "3g"}
# {"vocab": "삼성sch b360 블루블랙2"}
# {"vocab": "삼성UHD"}
# {"vocab": "컵냉동고"}
# {"vocab": "J RICHARD"}
# {"vocab": "킹덤 컴이지 코디101"}
# {"vocab": "갤럭시 탭 탭"}
# {"vocab": "메가 칩"}
# {"vocab": "D5300"}
# {"vocab": "레어카메라"}
# {"vocab": "부스트 DDR5"}
# {"vocab": "슈어 SE846블루"}
# {"vocab": "갤s10"}
# {"vocab": "갤럭시 TAB a6 LTE"}
# {"vocab": "late 2019"}
# {"vocab": "콘탁스 g1"}
# {"vocab": "앱코 s1000"}
# {"vocab": "피페이"}
# {"vocab": "리버브내장스피커"}
# {"vocab": "PNY XLR8 RTX 3080 Ti"}
# {"vocab": "WPU A400C"}
# {"vocab": "배민"}
# {"vocab": "Argus C3"}
# {"vocab": "E5645"}
# {"vocab": "앤틱캐논카메라"}
# {"vocab": "500grgb"}
# {"vocab": "abko 120mmrgb팬"}
# {"vocab": "로데 비디오 마이크로"}
# {"vocab": "에프터샥 오픈컴 블랙"}
# {"vocab": "DocuCentre IV 3060"}
# {"vocab": "Kt"}
# {"vocab": "캐리어 2in1"}
# {"vocab": "유선보드"}
# {"vocab": "로지텍 G PRO Wireless 슈퍼 라이트"}
# {"vocab": "kb1500"}
# {"vocab": "블루투스 기계식키보드"}
# {"vocab": "캐논10"}
# {"vocab": "CD MIC"}
# {"vocab": "아이디어패드 1080 모던 2060 프리스티지 F15 Omen G5 ROG"}
# {"vocab": "알리델D"}
# {"vocab": "뉴샤인"}
# {"vocab": "인터엠 MA 103 PA 앰프"}
# {"vocab": "줄후지필름"}
# {"vocab": "후지 인스탁"}
# {"vocab": "맥북프로맥북에어"}
# {"vocab": "후지"}
# {"vocab": "갤럭시A90 5G"}
# {"vocab": "MDR 888"}
# {"vocab": "슈어 se 215"}
# {"vocab": "ASROCK H410M"}
# {"vocab": "ASUS PRIME B350M"}
# {"vocab": "올림푸스E"}
# {"vocab": "AVR140"}
# {"vocab": "sch w480"}
# {"vocab": "쿠거 서팬션"}
# {"vocab": "갤럭시 z플립2"}
# {"vocab": "프리미어"}
# {"vocab": "BZ L7300"}
# {"vocab": "AM FM STEREO"}
# {"vocab": "코니카Z UP6031"}
# {"vocab": "스마트플레이스"}
# {"vocab": "STM캐논"}
# {"vocab": "3세대 i5 3570 아이비브릿지"}
# {"vocab": "스카이 im s550s"}
# {"vocab": "갈축 팜레스트"}
# {"vocab": "로지텍 402ic"}
# {"vocab": "야마하스피커"}
# {"vocab": "갤럭시 J3"}
# {"vocab": "EOD 60D"}
# {"vocab": "레어폰"}
# {"vocab": "LG 34UC79G"}
# {"vocab": "탭s7 wifi 128G"}
# {"vocab": "삼영"}
# {"vocab": "북 스캐너"}
# {"vocab": "NT750XDZ A51A"}
# {"vocab": "블리츠 ba c1"}
# {"vocab": "디지털컨버터"}
# {"vocab": "갤럭시북 이온2"}
# {"vocab": "갤럭시탭 s7fe lte"}
# {"vocab": "인버터 투도어"}
# {"vocab": "50mm f1 4 Ais"}
# {"vocab": "킹덤K2716F"}
# {"vocab": "i5 3550"}
# {"vocab": "인케"}
# {"vocab": "리모콘"}
# {"vocab": "philips com"}
# {"vocab": "스댕 그래파이트"}
# {"vocab": "SHV E330S"}
# {"vocab": "삼성 17000"}
# {"vocab": "AV리시앰프"}
# {"vocab": "Dell Precision 웍스테이션"}
# {"vocab": "라마르조꼬코리아"}
# {"vocab": "rtx30"}
# {"vocab": "x700 srt 101"}
# {"vocab": "바이올렛 블루"}
# {"vocab": "후지 인스탁스 미니 7"}
# {"vocab": "cpux570보드"}
# {"vocab": "범어사"}
# {"vocab": "맥북프로 터치바"}
# {"vocab": "엑소폰"}
# {"vocab": "X2300EW PLUS BRIGHT TN"}
# {"vocab": "알똘폰"}
# {"vocab": "LG 울트라"}
# {"vocab": "OLED65C1QNB"}
# {"vocab": "입문자용카메라"}
# {"vocab": "코어I3 256G"}
# {"vocab": "SL T1670"}
# {"vocab": "5600x기가바이트"}
# {"vocab": "큐센"}
# {"vocab": "스마트폴리오케이스"}
# {"vocab": "겸용복합카드단"}
# {"vocab": "EL34관"}
# {"vocab": "kp3400"}
# {"vocab": "에버 플러스홀릭폰"}
# {"vocab": "Charcoal"}
# {"vocab": "티비스타모니터tv"}
# {"vocab": "애플워치 3 4 5"}
# {"vocab": "갤럭시 GALAX RTX 3060 V2 D6"}
# {"vocab": "제온 L5640"}
# {"vocab": "KQ75QA65AFXKR"}
# {"vocab": "앱손잉크"}
# {"vocab": "15UD40N GX56K"}
# {"vocab": "클락 테크닉스"}
# {"vocab": "제주노트10"}
# {"vocab": "스타워즈 다스베이더"}
# {"vocab": "그램"}
# {"vocab": "옵시디안"}
# ...
# {"vocab": "맥북 프로 맥북프로"}
# {"vocab": "펜탁스 zoom 105 R"}
# {"vocab": "잘만 CNPS9X OPTIMA"}
# {"vocab": "삼성sch e250"}
# {"vocab": "엣지폰"}
# {"vocab": "갤럭시워치4 골프에디션"}
# {"vocab": "아이스크"}
# {"vocab": "LG트롬 드럼세탁기"}
# {"vocab": "후지카 하프"}
# {"vocab": "47LH50YD"}
# {"vocab": "T570 i5 7300U"}
# {"vocab": "e569"}
# {"vocab": "아이패드 프로5세대"}
# {"vocab": "A2230"}
# {"vocab": "터프 FX516PM HN002"}
# {"vocab": "에어패드4"}
# {"vocab": "데이트매틱 필름카메라"}
# {"vocab": "디즈니공주티비"}
# {"vocab": "액티브 스피커"}
# {"vocab": "W9100"}
# {"vocab": "로스트아크롤"}
# {"vocab": "스타2"}
# {"vocab": "바이오"}
# {"vocab": "아이폰 12 pro"}
# {"vocab": "hp스트림11"}
# {"vocab": "ASUS VG258QR"}
# {"vocab": "ax40"}
# {"vocab": "라이젠9 4세대 5900X"}
# {"vocab": "20캐논"}
# {"vocab": "55EC9310"}
# {"vocab": "KONICA C35101"}
# {"vocab": "갤럭시 탭 S7 LTE"}
# {"vocab": "ASUS PRIME B460M"}
# {"vocab": "LG IPS"}
# {"vocab": "Cambridge Audio 센터"}
# {"vocab": "P W"}
# {"vocab": "갤럭시 버즈 버즈"}
# {"vocab": "서피스 프로 7 i5"}
# {"vocab": "타블렛모니터"}
# {"vocab": "EB B3 B4 EC 8A A4 20251"}
# {"vocab": "N44 7"}
# {"vocab": "4K UHD TV"}
# {"vocab": "IPS UHD"}
# {"vocab": "본체 45G66 i5 4570"}
# {"vocab": "un60h6300"}
# {"vocab": "Hp프린터"}
# {"vocab": "로지텍 G Pro"}
# {"vocab": "세경냉동1200"}
# {"vocab": "Intel Core i5 6200U"}
# {"vocab": "i5 9400F GTX1060"}
# {"vocab": "AUTOBOY A38"}
# {"vocab": "GTX 650"}
# {"vocab": "대우전자본"}
# {"vocab": "바디캐논"}
# {"vocab": "저음사운드 스피커"}
# {"vocab": "pg s5000"}
# {"vocab": "톨보이 스피커"}
# {"vocab": "lgun550"}
# {"vocab": "천정형 인버터 냉난방기"}
# {"vocab": "KU 1700"}
# {"vocab": "스윙"}
# {"vocab": "비츠 솔로 프로"}
# {"vocab": "슈퍼울트라"}
# {"vocab": "SLC 116"}
# {"vocab": "배그 디아블로2레저렉션"}
# {"vocab": "엠스톤 sf"}
# {"vocab": "장패드서비스"}
# {"vocab": "아이패드 7세대 128 스페이스 그레이"}
# {"vocab": "제이로드"}
# {"vocab": "사운드베이스"}
# {"vocab": "i5 4세대 GT 740"}
# {"vocab": "커브드 와이드 모니터"}
# {"vocab": "APU HD 7640G"}
# {"vocab": "JBL헤드셋"}
# {"vocab": "오토렌즈캡가리즈"}
# {"vocab": "시그마14"}
# {"vocab": "찬냉장고"}
# {"vocab": "B510S"}
# {"vocab": "오멘 라이젠7 5800H"}
# {"vocab": "미밴드6"}
# {"vocab": "LG 23ET63"}
# {"vocab": "펜톤"}
# {"vocab": "LG 그램 15Z950 GT30K"}
# {"vocab": "삼성 SF 250"}
# {"vocab": "OIO"}
# {"vocab": "맥북에어13 M1"}
# {"vocab": "C4udf"}
# {"vocab": "모니터 24ML600SW"}
# {"vocab": "배그 PC"}
# {"vocab": "삼성커브드모니터"}
# {"vocab": "SSD카드"}
# {"vocab": "블랙하이엔드광학10"}
# {"vocab": "LG LV8500"}
# {"vocab": "딥네이비색상"}
# {"vocab": "WD"}
# {"vocab": "CANON EOS M50"}
# {"vocab": "sph x7019"}
# {"vocab": "vk x100"}
# {"vocab": "레노버 P53 RTX3000"}
# {"vocab": "14인치 m1 pro"}
# {"vocab": "알리코"}
# {"vocab": "SOLO 120"}
# {"vocab": "택포 버즈 플러스"}
# {"vocab": "ECK"}
# {"vocab": "t500rs"}
# {"vocab": "미션 스피커"}
# {"vocab": "아이패드 에어 1"}
# {"vocab": "삼성지펠퍼니쳐스타일냉장고"}
# {"vocab": "Mini"}
# {"vocab": "조텍 RTX3070 Edge OC 파 워"}
# {"vocab": "네이비"}
# {"vocab": "블루버드pda BIP1300"}
# {"vocab": "lg lp4500"}
# {"vocab": "캐리어 인버터"}
# {"vocab": "갤럭시 버즈프로"}
# {"vocab": "솔라파워 쇼케이스"}
# {"vocab": "미라클m200"}
# {"vocab": "무선오"}
# {"vocab": "델 레티튜드 E7270 i7"}
# {"vocab": "HDD 500 640 750"}
# {"vocab": "OFC 4N"}
# {"vocab": "인텔9세대 I5 9400F GTX1060"}
# {"vocab": "intager"}
# {"vocab": "18핀 충전기"}
# {"vocab": "로지텍G913 tkl"}
# {"vocab": "NT900X5L K25D"}
# {"vocab": "sony a6400"}
# {"vocab": "nvme256 1T"}
# {"vocab": "갤럭시 워치1 46MM R805"}
# {"vocab": "kr녹축"}
# {"vocab": "무선고속충전기"}
# {"vocab": "asus프라임윈10"}
# {"vocab": "NVMe 2200"}
# {"vocab": "필름 5000"}
# {"vocab": "POWE"}
# {"vocab": "삼성레이져팩스SCX4833FD"}
# {"vocab": "까만색"}
# {"vocab": "DSLR D40X AF50"}
# {"vocab": "엑토 레트로 미니 무선 키보드"}
# {"vocab": "웰릭스렌탈"}
# {"vocab": "R R SEC S27AM500N"}
# {"vocab": "EW 63C"}
# {"vocab": "HP Z820"}
# {"vocab": "아이폰12PRO"}
# {"vocab": "시에라블루"}
# {"vocab": "송해교폰"}
# {"vocab": "sch s200"}
# {"vocab": "i3 CPU"}
# {"vocab": "배틀그라운드 뉴스테이트"}
# {"vocab": "크레마 카르타G"}
# {"vocab": "블린즈 스마트워치"}
# {"vocab": "70,000i7"}
# {"vocab": "PC4 21300"}
# {"vocab": "미니컴퓨터"}
# {"vocab": "갤럭시 북 S"}
# {"vocab": "캐논 400d"}
# {"vocab": "25 GhzASUS"}
# {"vocab": "DDR4 8GB"}
# {"vocab": "Graflex Speed Graphic"}
# {"vocab": "삼성 비스포크 에어드레서"}
# {"vocab": "해커 B510U"}
# {"vocab": "노트북키보드"}
# {"vocab": "파나소닉 14 42 줌"}
# {"vocab": "LG SD910"}
# {"vocab": "히트펌프"}
# {"vocab": "ZM K400G"}
# {"vocab": "엘지sb9230"}
# {"vocab": "리퍼TV"}
# {"vocab": "팔름"}
# {"vocab": "노트9"}
# {"vocab": "미드나이"}
# {"vocab": "NVMe SSD"}
# {"vocab": "태블릿4"}
# {"vocab": "램16 SSD"}
# {"vocab": "와일드헌"}
# {"vocab": "앱코N550"}
# {"vocab": "S24R356"}
# {"vocab": "QC 이어버드"}
# {"vocab": "BX500"}
# {"vocab": "2 00 GHzRAM"}
# {"vocab": "구찌"}
# {"vocab": "EOS M3 블랙"}
# {"vocab": "소니노트북램"}
# {"vocab": "500GUSB"}
# {"vocab": "회전 스피커"}
# {"vocab": "현대 Z 70"}
# {"vocab": "아그파매틱 4000디피"}
# {"vocab": "PF3210HD"}
# {"vocab": "라이젠 3000G"}
# {"vocab": "키마셋"}
# {"vocab": "보라색"}
# {"vocab": "QC이어버드"}
# {"vocab": "eos600d"}
# {"vocab": "sch e135"}
# {"vocab": "맥북에어2014"}
# {"vocab": "Haier"}
# {"vocab": "에이텍Al220w"}
# {"vocab": "400 500"}
# {"vocab": "UNI FAN AL120 BLACK"}
# {"vocab": "아이폰 12PROMAX"}
# {"vocab": "Randeon Pro 555x"}
# {"vocab": "W170 D530 H460"}
# {"vocab": "hp 스캐너"}
# {"vocab": "bcs t90"}
# {"vocab": "USB LED"}
# {"vocab": "미놀타 하이매틱 AF 카메라"}
# {"vocab": "갤럭시20"}
# {"vocab": "CU편"}
# {"vocab": "현대아피트"}
# {"vocab": "더키 원2"}
# {"vocab": "니코르렌즈"}
# {"vocab": "밴큐 XL2720"}
# {"vocab": "상"}
# {"vocab": "갤럭시워치 42mm"}
# {"vocab": "델 P54G노트북"}
# {"vocab": "모토토라배터리"}
# {"vocab": "LV8500"}
# {"vocab": "옵시디언 미스트 스포츠밴드"}
# {"vocab": "VerveBuds 150"}
# {"vocab": "X9 920 타이탄"}
# {"vocab": "조이트론 EX SQUAD PC"}
# {"vocab": "32gb메모리"}
# {"vocab": "클립쉬 더쓰리2"}
# {"vocab": "sch b900"}
# {"vocab": "미라크"}
# {"vocab": "삼성노트북7"}
# {"vocab": "스카이 im s410k"}
# {"vocab": "삼성sch s260"}
# {"vocab": "라벤더 퍼플 미니11"}
# {"vocab": "파워엠프"}
# {"vocab": "Hp OfficeJet 4650"}
# {"vocab": "록 아웃 스피커"}
# {"vocab": "dcinside"}
# {"vocab": "아이패드 5세대 프로"}
# {"vocab": "갤럭시북 NT750XDZ A51A15"}
# {"vocab": "브리츠 블루트스"}
# {"vocab": "LG울트라북 15U340 LT1CK"}
# {"vocab": "k995p v3"}
# {"vocab": "삼성NX100"}
# {"vocab": "구글 네스트 허브"}
# {"vocab": "1000XM2BM"}
# {"vocab": "나이키밴드"}
# {"vocab": "슬림슬라이드폰"}
# {"vocab": "니콘 70"}
# {"vocab": "성일초등학교"}
# {"vocab": "하드1테라"}
# {"vocab": "LCD LED"}
# {"vocab": "ck420"}
# {"vocab": "프리즘 화이트"}
# {"vocab": "얼티epic"}
# {"vocab": "미세기스무잔상도보"}
# {"vocab": "LG 32LW4500"}
# {"vocab": "알파350"}
# {"vocab": "삼성기어 3프론티어"}
# {"vocab": "K27MF144"}
# {"vocab": "갤럭시 버즈1"}
# {"vocab": "A660 3325"}
# {"vocab": "LG에어컨"}
# {"vocab": "전기 마사지기"}
# {"vocab": "A2E 35 80mm f4"}
# {"vocab": "옵티컬 퍼플"}
# {"vocab": "터치모니터"}
# {"vocab": "우퍼스피커"}
# {"vocab": "포카리"}
# {"vocab": "카트"}
# {"vocab": "AIBIMY"}
# {"vocab": "사운드바2"}
# {"vocab": "LP156WD1 TL A2"}
# {"vocab": "MPG27CQ"}
# {"vocab": "ASUS RTX3070"}
# {"vocab": "크롬 카메라뮤"}
# {"vocab": "삼성갤럭시 노트20울트라"}
# {"vocab": "A426 그레이"}
# {"vocab": "라이노 아이패드 에어3"}
# {"vocab": "202114ZD90P GX50K"}
# {"vocab": "블루투스데스크탑게이밍스피커"}
# {"vocab": "i5CPU"}
# {"vocab": "NIKON F65 AF50 8D"}
# {"vocab": "희귀큐리텔 ps e100"}
# {"vocab": "13 3 레티나"}
# {"vocab": "PE"}
# {"vocab": "스프링코드"}
# {"vocab": "프리즘코리아"}
# {"vocab": "접착프린터"}
# {"vocab": "인터엠"}
# {"vocab": "트리니트론 450Tvline"}
# {"vocab": "LG LV390"}
# {"vocab": "DSC RX100M5"}
# {"vocab": "정격700W 80"}
# {"vocab": "위니아 쁘띠 미니 냉장고"}
# {"vocab": "판도라 필름카메라"}
# {"vocab": "E04"}
# {"vocab": "23인치 EX2351"}
# {"vocab": "IK 200 시리즈"}
# {"vocab": "gtx960지포스 gtx970"}
# {"vocab": "i5 10400"}
# {"vocab": "SCX 1365"}
# {"vocab": "ux32vd"}
# {"vocab": "뱅엔올룹슨 H5 Wireless headphone Bang Olufsen Beoplay H5 Wireless Headphones Splash Dust Resistant Black"}
# {"vocab": "M 어뎁터"}
# {"vocab": "LG와이드모니터 29WN600"}
# {"vocab": "Crucial MX200"}
# {"vocab": "캐논 프리마 90"}
# {"vocab": "NZXT C850 80Plus Full Modular"}
# {"vocab": "아이폰se"}
# {"vocab": "갤럭시ON7"}
# {"vocab": "UN82TU7000FXZALG"}
# {"vocab": "휴대용모니터"}
# {"vocab": "201632GBwifi"}
# {"vocab": "라이젠3 2200G"}
# {"vocab": "SCH B680"}
# {"vocab": "MFR G1"}
# {"vocab": "무선전화기"}
# {"vocab": "우먼스999"}
# {"vocab": "씨메mac75"}
# {"vocab": "북셀프 스피커"}
# {"vocab": "블랙실버"}
# {"vocab": "스튜디오"}
# {"vocab": "은장실버"}
# {"vocab": "갤럭시 탭 S6 라이트"}
# {"vocab": "원노트"}
# {"vocab": "하이퍼X Cloud revolver S"}
# {"vocab": "F17VDAP"}
# {"vocab": "27UK650"}
# {"vocab": "Beoplay H4 B O Bang Olufsen Beoplay H4 Wireless Headphones"}
# {"vocab": "CT10"}
# {"vocab": "후지 필름"}
# {"vocab": "유선헤드셋"}
# {"vocab": "75인치 T7503TU"}
# {"vocab": "노인폰"}
# {"vocab": "2 8GHzSSD"}
# {"vocab": "데스크탑"}
# {"vocab": "B350 PRO"}
# {"vocab": "DSO H168"}
# {"vocab": "ASUS PH GTX 1650 O4G D6"}
# {"vocab": "ck800"}
# {"vocab": "토체티 텐키리스"}
# {"vocab": "미니 레트로 클래식"}
# {"vocab": "맥킨토시"}
# {"vocab": "S 36"}
# {"vocab": "A1707"}
# {"vocab": "전지현"}
# {"vocab": "테클라스트"}
# {"vocab": "갤럭시진2 A202"}
# {"vocab": "4GSSD"}
# {"vocab": "갤럭시 j5 2016"}
# {"vocab": "아이나비 Z5000플러스"}
# {"vocab": "사이안색"}
# {"vocab": "올림프스 ALT T 텔레 38 60mm P S 필카"}
# {"vocab": "미놀타 AF E 카메라"}
# {"vocab": "갤럭시s8 실버"}
# {"vocab": "오천사"}
# {"vocab": "후지 카디아 씨"}
# {"vocab": "SU430"}
# {"vocab": "센서"}
# {"vocab": "미러리스 EOS M100블랙"}
# {"vocab": "100D"}
# {"vocab": "갤럭시플레이어"}
# {"vocab": "블랙위도우"}
# {"vocab": "얼티메"}
# {"vocab": "카디아 슈퍼 312"}
# {"vocab": "갤럭시S21 3954"}
# {"vocab": "튜"}
# {"vocab": "LCM400AB"}
# {"vocab": "홈허브 공유기"}
# {"vocab": "LG15U760 G AR30K i3 5005U"}
# {"vocab": "퀀텀미니"}
# {"vocab": "젠북 듀오 14"}
# {"vocab": "제니트 필름"}
# {"vocab": "a6400"}
# {"vocab": "gtx 1070"}
# {"vocab": "23 2"}
# {"vocab": "i5 2400메모리"}
# {"vocab": "소니미러리스"}
# {"vocab": "dslr 700D"}
# {"vocab": "x32ra"}
# {"vocab": "엘지 SH150"}
# {"vocab": "에어팟 프로 맥스"}
# {"vocab": "큐닉스 144HZ"}
# {"vocab": "F27T702"}
# {"vocab": "LP e17"}
# {"vocab": "블루투스 v5 0 SBC AAC A2DP AVRCP HFP AUX"}
# {"vocab": "LG 828"}
# {"vocab": "귀뚜라미"}
# {"vocab": "rne"}
# {"vocab": "커피머신"}
# {"vocab": "앱손L8180"}
# {"vocab": "데스크탑PC"}
# {"vocab": "Z플립1"}
# {"vocab": "W8ii DUO"}
# {"vocab": "니콘세로그립"}
# {"vocab": "삼성비스포크"}
# {"vocab": "캐논 파워샷 SX50HS"}
# {"vocab": "A7M3"}
# {"vocab": "m50 m50 화이트"}
# {"vocab": "AT818 다이나믹"}
# {"vocab": "공학계산기"}
# {"vocab": "scx 1360"}
# {"vocab": "acer 크롬북"}
# {"vocab": "스포츠밴"}
# {"vocab": "ATLANTIC 200"}
# {"vocab": "amd ryzen 5600x"}
# {"vocab": "보조 배터리"}
# {"vocab": "PC4 21300 X2"}
# {"vocab": "액션캠"}
# {"vocab": "x32컴팩트"}
# {"vocab": "삼성 디지탈 애니콜 플립 캠코더폰"}
# {"vocab": "dell se2717h"}
# {"vocab": "판도라사"}
# {"vocab": "IPS 클라우드"}
# {"vocab": "전자사전"}
# {"vocab": "에스파 윈터"}
# {"vocab": "아이패드 에어3 에플펜슬"}
# {"vocab": "키티"}
# {"vocab": "QHD VA"}
# {"vocab": "GSW i7"}
# {"vocab": "ZOOM"}
# {"vocab": "스터디카페POS"}
# {"vocab": "터치스크린코어i5"}
# {"vocab": "젤센 노이즈캔슬링"}
# {"vocab": "팬티엄 램8G SSD128 500G"}
# {"vocab": "F4S"}
# {"vocab": "프론트 플로어스텐딩"}
# {"vocab": "24 105 lens"}
# {"vocab": "DN 780"}
# {"vocab": "coupang com"}
# {"vocab": "be mp1000"}
# {"vocab": "유니하이테크"}
# {"vocab": "갤럭시북s LTE"}
# {"vocab": "sk2g 스카이 핸디 im s200k"}
# {"vocab": "liqmax 3"}
# {"vocab": "캐논오토보이 F 블랙바디"}
# {"vocab": "게이밍 커브드 모니터"}
# {"vocab": "버블팝"}
# {"vocab": "JN153B cel 2957"}
# {"vocab": "괴물스피커"}
# {"vocab": "삼성칼라복합기SCX1365"}
# {"vocab": "R522 T6670"}
# {"vocab": "커세어 아이언클로"}
# {"vocab": "삼성태블릿패드"}
# {"vocab": "아이폰 13 프로 맥스"}
# {"vocab": "INBAG"}
# {"vocab": "델베뉴 8프로 3000"}
# {"vocab": "턴테이블"}
# {"vocab": "sk 3g"}
# {"vocab": "MP3 레트로 클래식"}
# {"vocab": "체리 MX BOARD3 0 S"}
# {"vocab": "s7 fe 64 wifi"}
# {"vocab": "koreSubPlacement"}
# {"vocab": "크리이톡스 105"}
# {"vocab": "파이어8"}
# {"vocab": ", 6 플러스"}
# {"vocab": "로지텍g1"}
# {"vocab": "kt2g"}
# {"vocab": "4411s"}
# {"vocab": "전기히"}
# {"vocab": "로그래"}
# {"vocab": "안드로이드 에프쓰리"}
# {"vocab": "GIGABYTE GA 85 M HD3"}
# {"vocab": "셀룰러 LTE 32G 90"}
# {"vocab": "티머니"}
# {"vocab": "RAZER"}
# {"vocab": "히타치"}
# {"vocab": "노트북i7"}
# {"vocab": "탐론18 200 XR Di2 랜즈"}
# {"vocab": "야모"}
# {"vocab": "아이패드 매직키보드"}
# {"vocab": "야시카 일렉트로 35 GSN"}
# {"vocab": "플랫브라운"}
# {"vocab": "x70"}
# {"vocab": "su40dk"}
# {"vocab": "로즈골드색"}
# {"vocab": "stuv4"}
# {"vocab": "캐논60D"}
# {"vocab": "갤럭시 탭S7 LTE 128G"}
# {"vocab": "삼성 NX10"}
# {"vocab": "BONO BOSS P330"}
# {"vocab": "CF"}
# {"vocab": "팝필"}
# {"vocab": "뮤 줌 파노라마"}
# {"vocab": "oa sp600"}
# {"vocab": "한성컴퓨토"}
# {"vocab": "LUMIX LX5"}
# {"vocab": "GarageBand"}
# {"vocab": "giro90"}
# {"vocab": "미니 녹음기"}
# {"vocab": "HVL F60RM 플래시"}
# {"vocab": "CYP"}
# {"vocab": "DSLR카메라"}
# {"vocab": "9 7형 Wi Fi"}
# {"vocab": "인터엠 PG 6140"}
# {"vocab": "라디오튜너"}
# {"vocab": "스타크래프트2"}
# {"vocab": "인스탁스 폴라로이드"}
# {"vocab": "씽크패드 X1 요가"}
# {"vocab": "g3"}
# {"vocab": "다크플래시"}
# {"vocab": "HP칼라레이져프린터"}
# {"vocab": "포트라400VC"}
# {"vocab": "eosm10"}
# {"vocab": "FE 24 240mm A7M2"}
# {"vocab": "애플케어23"}
# {"vocab": "dsl"}
# {"vocab": "ASUS ROG STRIX 지포스 RTX 3070ti 08 GAMING OC D6X"}
# {"vocab": "원스텝 플러스 폴라로이드 원스텝 플러스 폴라로이드"}
# {"vocab": "케이스 7 8 se2"}
# {"vocab": "productList 10650789"}
# {"vocab": "워치 4"}
# {"vocab": "지패드"}
# {"vocab": "맥북에어 MGN63KH A"}
# {"vocab": "40mm 블랙"}
# {"vocab": "14Z90N U AAS7U1"}
# {"vocab": "가죽 스"}
# {"vocab": "실리콘밴"}
# {"vocab": "JBL Quantum DUO 퀀텀 듀오 스피커"}
# {"vocab": "Dual Core SSD128 HDD590"}
# {"vocab": "Canon EOS M10"}
# {"vocab": "후폰"}
# {"vocab": "Rev A"}
# {"vocab": "엘지 15U550 i5 5200U"}
# {"vocab": "흑백 칼"}
# {"vocab": "AMD Mobility Radeon HD 5000serie"}
# {"vocab": "DMB"}
# {"vocab": "실버 983"}
# {"vocab": "큐센키보드"}
# {"vocab": "벤큐xl2411p"}
# {"vocab": "지포스 RTX 3060"}
# {"vocab": "MC979KH A"}
# {"vocab": "니콘 55"}
# {"vocab": "스카이붐붐 IM U160L"}
# {"vocab": "미놀타200mm"}
# {"vocab": "롤 서든 배그"}
# {"vocab": "카멜마운트 SB65"}
# {"vocab": "lt27a750"}
# {"vocab": "아이패드 7세대"}
# {"vocab": "shw m110s갤럭시s1"}
# {"vocab": "LZ"}
# {"vocab": "Intel Core i5LCD"}
# {"vocab": "패시브스피커"}
# {"vocab": "후지 플래시"}
# {"vocab": "갤럭시워치 42mm R815"}
# {"vocab": "풀프레임 미러리스 A7m2"}
# {"vocab": "삼성 850 PRO SATA Port 1"}
# {"vocab": "KU4000"}
# {"vocab": "엑티브워시 세탁기"}
# {"vocab": "싱싱냉장고"}
# {"vocab": "S21 울트라"}
# {"vocab": "win10 OS"}
# {"vocab": "파워비츠 프로 POWERBEATS PRO"}
# {"vocab": "미니안테나폰"}
# {"vocab": "카트라이더 러쉬 플러스 닉"}
# {"vocab": "아메리칸 오디오사"}
# {"vocab": "아콘fx"}
# {"vocab": "콘프로 에어 화이트"}
# {"vocab": "구큐플"}
# {"vocab": "폴드1,2,3"}
# {"vocab": "스피커블"}
# {"vocab": "니시카 N9000"}
# {"vocab": "블루투스 무드등"}
# {"vocab": "SLR 필름카메라"}
# {"vocab": "sk22"}
# {"vocab": "황금맷돌"}
# {"vocab": "레쉬"}
# {"vocab": "산돌이폰"}
# {"vocab": "Genelec 8010a"}
# {"vocab": "SD 305"}
# {"vocab": "DF10A9500CG"}
# {"vocab": "LG 그램16 16ZD90P"}
# {"vocab": "파나소닉 루믹스 s1"}
# {"vocab": "YouTube,"}
# {"vocab": "에이조"}
# {"vocab": "로우앵글 파인더"}
# {"vocab": "F2"}
# {"vocab": "그래픽카"}
# {"vocab": "디스펜"}
# {"vocab": "주닉스"}
# {"vocab": "아이폰 6s"}
# {"vocab": "코콤"}
# {"vocab": "러브액츄얼리폰"}
# {"vocab": "팬택큐리텔 PT K1300"}
# {"vocab": "OFF 센서"}
# {"vocab": "sunpak888afz"}
# {"vocab": "SOS폰"}
# {"vocab": "갤럭시s7"}
# {"vocab": "emmc"}
# {"vocab": "갤럭시s10e"}
# {"vocab": "VOGEN MF 2000"}
# {"vocab": "인스픽스"}
# {"vocab": "Eris E3 5 BT"}
# {"vocab": "중고신품모니"}
# {"vocab": "스카이 im u660k"}
# {"vocab": "cto맥북프로"}
# {"vocab": "SK2G 576"}
# {"vocab": "DS5802Z"}
# {"vocab": "E5 2650 v1"}
# {"vocab": "후지사"}
# {"vocab": "JBL파티박스"}
# {"vocab": "2G폰sk"}
# {"vocab": "LG와인3폴더"}
# {"vocab": "nvme2"}
# {"vocab": "C27T550"}
# {"vocab": "추엽원"}
# {"vocab": "오울아이"}
# {"vocab": "fullhd TV"}
# {"vocab": "kt"}
# {"vocab": "김장독"}
# {"vocab": "yamah"}
# {"vocab": ", 13프로"}
# {"vocab": "화웨이"}
# {"vocab": "유디아 200헤르츠 hz"}
# {"vocab": "위스키레이크 코어"}
# {"vocab": "번개페이"}
# {"vocab": "김밥토핑냉장고"}
# {"vocab": "에어팟 3세대"}
# {"vocab": "T5088"}
# {"vocab": "갤럭시 워치"}
# {"vocab": "삼성슬림"}
# {"vocab": "캐논 오토보이 루나 xl"}
# {"vocab": "갤럭시 버즈 라이브 SM R180"}
# {"vocab": "스타택 7760"}
# {"vocab": "Sticky Note Printer MIP 101B"}
# {"vocab": "오디오테크니카"}
# {"vocab": "한성포터블모니터"}
# {"vocab": "포토 스나이퍼 카메라"}
# {"vocab": "35WN65C"}
# {"vocab": "쵸파"}
# {"vocab": "메인보"}
# {"vocab": "P U"}
# {"vocab": "이어소닉스"}
# {"vocab": "sch m450"}
# {"vocab": "인텔 코어i5 2500"}
# {"vocab": "후지카 35 오토 M 필름카메라"}
# {"vocab": "삼성32"}
# {"vocab": "9900에어3"}
# {"vocab": "호루스벤누"}
# {"vocab": "갤럭시A6 실버"}
# {"vocab": "갤럭시A90 블랙"}
# {"vocab": "PH1"}
# {"vocab": "860Evo"}
# {"vocab": ",hs7000,canu801ex"}
# {"vocab": "lg oled 55"}
# {"vocab": "LG RB510 노트북윈10프로"}
# {"vocab": "GK30K"}
# {"vocab": "딜리코 펠리체 블렌더"}
# {"vocab": "ef p"}
# {"vocab": "키캡8 리무버"}
# {"vocab": "노트 10"}
# {"vocab": "키티 빈"}
# {"vocab": "아이폰11pro 256"}
# {"vocab": "27gk750f"}
# {"vocab": "64오디오"}
# {"vocab": "Polk Hampden"}
# {"vocab": "3Dkvawf09s 7Cci"}
# {"vocab": "MSI RAM DDR3"}
# {"vocab": "EOS650"}
# {"vocab": "니건조기"}
# {"vocab": "Fhd"}
# {"vocab": "ARC"}
# {"vocab": "sj4000"}
# {"vocab": "100 프로"}
# {"vocab": "아이패드 10 5 프로 셀룰러"}
# {"vocab": "크리스털"}
# {"vocab": "msea"}
# {"vocab": "갤럭시노트10플러스메모리"}
# {"vocab": "오픈프레임"}
# {"vocab": "128GIGA WiFi"}
# {"vocab": "ppt"}
# {"vocab": "20QN001FUSRTX3000"}
# {"vocab": "16gasus tuf"}
# {"vocab": "앤틱갤러리"}
# {"vocab": "애플워치 밴드 아이스드 아웃"}
# {"vocab": "일렉트로"}
# {"vocab": "델 s2417dg"}
# {"vocab": "와콤 인튜어스 4"}
# {"vocab": "이건희폰"}
# {"vocab": "아마존 파이어 테블릿"}
# {"vocab": "케이스티파이"}
# {"vocab": "휴이온 액정타블랫 캄바스 프로 24"}
# {"vocab": "JBL 1000w"}
# {"vocab": "시리얼"}
# {"vocab": "n115"}
# {"vocab": "5CH"}
# {"vocab": "삼성 NEW 4K QLEDTV"}
# {"vocab": "필림 카메라"}
# {"vocab": "LG 인버터 전기건조기"}
# {"vocab": "갤럭시A12 블랙"}
# {"vocab": "NT500R3W"}
# {"vocab": "파이널 e500"}
# {"vocab": "랜카드"}
# {"vocab": "Fz300"}
# {"vocab": "쿠쿠인스퓨어"}
# {"vocab": "지마스터"}
# {"vocab": "Harman Kardon 20W Speaker"}
# {"vocab": "HGI"}
# {"vocab": "농 협"}
# {"vocab": "50mm f1 7 Z113"}
# {"vocab": "DP M109 이퀄라이저"}
# {"vocab": "엘지양문형냉장고"}
# {"vocab": "출퇴근관리"}
# {"vocab": "SONY ILCE QX1L"}
# {"vocab": "스테인리스 LTE"}
# {"vocab": "SM T515N"}
# {"vocab": "ERT118CP"}
# {"vocab": "K58D"}
# {"vocab": "한진택배"}
# {"vocab": "갤럭시 버즈 프로 플립3"}
